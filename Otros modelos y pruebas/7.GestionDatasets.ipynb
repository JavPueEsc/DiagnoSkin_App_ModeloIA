# %% [markdown]
# # Comprobación estructura archivo .csv

# %%
import os
import pandas as pd

# Ruta del archivo CSV
csv_train = "PAD-UFES-20/metadata.csv"

# Cargar los datos
df_train = pd.read_csv(csv_train)

# Mostrar algunas filas
print(df_train.head())

# Esto te permitirá ver cómo están organizadas las etiquetas. 
# Normalmente, el CSV tendrá columnas como "image_name" (nombre del archivo de la imagen) 
# y "label" (la clase a la que pertenece la imagen).
# Out:
#   patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0   PAT_1516       1765    NaN    NaN               NaN               NaN
# 1     PAT_46        881  False  False         POMERANIA         POMERANIA
# 2   PAT_1545       1867    NaN    NaN               NaN               NaN
# 3   PAT_1989       4061    NaN    NaN               NaN               NaN
# 4    PAT_684       1302  False   True         POMERANIA         POMERANIA
#
#    age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# 0    8       NaN     NaN                 NaN  ...        NaN        NEV
# 1   55     False  FEMALE                True  ...        5.0        BCC
# 2   77       NaN     NaN                 NaN  ...        NaN        ACK
# 3   75       NaN     NaN                 NaN  ...        NaN        ACK
# 4   79     False    MALE                True  ...        5.0        BCC
#
#     itch   grew   hurt  changed  bleed elevation                 img_id  \
# 0  False  False  False    False  False     False  PAT_1516_1765_530.png
# 1   True   True  False     True   True      True     PAT_46_881_939.png
# 2   True  False  False    False  False     False  PAT_1545_1867_547.png
# 3   True  False  False    False  False     False  PAT_1989_4061_934.png
# 4   True   True  False    False   True      True   PAT_684_1302_588.png
#
#   biopsed
# 0   False
# 1    True
# 2   False
# 3   False
# 4    True
#
# [5 rows x 26 columns]

# %% [markdown]
# # Clasificación por carpetas según patología

# %%
import os
import shutil
import pandas as pd
import re

# Ruta donde están las imágenes originales
carpeta_imagenes = 'PAD-UFES-20'  # <-- cambia esta ruta

# Cargar el CSV que contiene el nombre de archivo e información de diagnóstico
df = pd.read_csv('PAD-UFES-20/metadata.csv')  # <-- cambia esta ruta

# Reemplazar valores nulos por 'unknown'
df['diagnostic'] = df['diagnostic'].fillna('unknown')

# Función para limpiar nombres de carpeta
def limpiar_nombre(nombre):
    return re.sub(r'[^\w\-_. ]', '_', str(nombre).strip())

# Ruta de salida
output_folder = 'imagenes_clasificadas_PAD-UFES-20'

# Crear carpeta base si no existe
os.makedirs(output_folder, exist_ok=True)

# Procesar cada imagen
for _, fila in df.iterrows():
    nombre_archivo = fila['img_id']  # <-- columna con el nombre del archivo de imagen
    categoria = limpiar_nombre(fila['diagnostic'])

    carpeta_destino = os.path.join(output_folder, categoria)
    os.makedirs(carpeta_destino, exist_ok=True)

    ruta_origen = os.path.join(carpeta_imagenes, nombre_archivo)
    ruta_destino = os.path.join(carpeta_destino, nombre_archivo)

    try:
        shutil.copy2(ruta_origen, ruta_destino)
        print(f"Copiada: {nombre_archivo} → {categoria}")
    except FileNotFoundError:
        print(f"❌ Archivo no encontrado: {ruta_origen}")
# Out:
# Copiada: PAT_1516_1765_530.png → NEV
# Copiada: PAT_46_881_939.png → BCC
# Copiada: PAT_1545_1867_547.png → ACK
# Copiada: PAT_1989_4061_934.png → ACK
# Copiada: PAT_684_1302_588.png → BCC
# Copiada: PAT_1549_1882_230.png → SEK
# Copiada: PAT_778_1471_835.png → BCC
# Copiada: PAT_117_179_983.png → BCC
# Copiada: PAT_1995_4080_695.png → ACK
# Copiada: PAT_705_4015_413.png → ACK
# Copiada: PAT_2140_4726_141.png → ACK
# Copiada: PAT_967_1827_247.png → BCC
# Copiada: PAT_2088_4524_465.png → NEV
# Copiada: PAT_636_1204_521.png → BCC
# Copiada: PAT_38_54_234.png → BCC
# Copiada: PAT_741_1401_619.png → BCC
# Copiada: PAT_380_1540_959.png → SCC
# Copiada: PAT_1783_3414_120.png → SEK
# Copiada: PAT_759_1538_566.png → BCC
# Copiada: PAT_821_1547_77.png → BCC
# Copiada: PAT_1693_3103_879.png → ACK
# Copiada: PAT_875_1668_588.png → BCC
# Copiada: PAT_1653_2916_346.png → SEK
# Copiada: PAT_1790_3425_942.png → SEK
# Copiada: PAT_106_159_325.png → BCC
# Copiada: PAT_435_854_68.png → BCC
# Copiada: PAT_1902_3790_168.png → SEK
# Copiada: PAT_42_58_13.png → BCC
# Copiada: PAT_302_651_529.png → BCC
# Copiada: PAT_359_4450_86.png → ACK
# Copiada: PAT_107_160_609.png → SEK
# Copiada: PAT_134_201_587.png → BCC
# Copiada: PAT_1453_1567_250.png → NEV
# Copiada: PAT_79_120_532.png → BCC
# Copiada: PAT_1926_3871_371.png → SEK
# Copiada: PAT_724_1369_896.png → BCC
# Copiada: PAT_1582_2574_34.png → SEK
# Copiada: PAT_1006_53_716.png → ACK
# Copiada: PAT_1431_1495_511.png → ACK
# Copiada: PAT_944_1795_371.png → BCC
# Copiada: PAT_793_1512_327.png → NEV
# Copiada: PAT_394_1562_579.png → BCC
# Copiada: PAT_1842_3615_850.png → NEV
# Copiada: PAT_621_1183_56.png → NEV
# Copiada: PAT_374_762_794.png → ACK
# Copiada: PAT_265_406_276.png → BCC
# Copiada: PAT_1074_322_662.png → ACK
# Copiada: PAT_289_1399_481.png → ACK
# Copiada: PAT_1803_3463_639.png → NEV
# Copiada: PAT_1029_135_239.png → ACK
# Copiada: PAT_2020_4174_799.png → ACK
# Copiada: PAT_682_1292_986.png → BCC
# Copiada: PAT_805_1517_154.png → SCC
# Copiada: PAT_680_1289_182.png → MEL
# Copiada: PAT_53_1370_245.png → BCC
# Copiada: PAT_868_1657_698.png → ACK
# Copiada: PAT_183_283_495.png → SCC
# Copiada: PAT_479_919_97.png → BCC
# Copiada: PAT_333_1469_499.png → NEV
# Copiada: PAT_867_1650_901.png → BCC
# Copiada: PAT_236_361_180.png → ACK
# Copiada: PAT_620_1176_980.png → BCC
# Copiada: PAT_26_37_865.png → ACK
# Copiada: PAT_2051_4356_460.png → ACK
# Copiada: PAT_1381_1314_517.png → ACK
# Copiada: PAT_544_3299_671.png → SEK
# Copiada: PAT_2025_4229_541.png → ACK
# Copiada: PAT_814_1532_545.png → BCC
# Copiada: PAT_1014_86_861.png → ACK
# Copiada: PAT_1984_4038_265.png → NEV
# Copiada: PAT_920_1747_19.png → BCC
# Copiada: PAT_838_1585_282.png → BCC
# Copiada: PAT_1255_876_939.png → ACK
# Copiada: PAT_701_4056_457.png → SEK
# Copiada: PAT_411_815_692.png → SEK
# Copiada: PAT_795_1508_925.png → ACK
# Copiada: PAT_288_441_312.png → BCC
# Copiada: PAT_692_1308_364.png → BCC
# Copiada: PAT_1278_965_701.png → ACK
# Copiada: PAT_1094_381_85.png → ACK
# Copiada: PAT_645_4043_374.png → ACK
# Copiada: PAT_963_1820_823.png → ACK
# Copiada: PAT_241_367_89.png → BCC
# Copiada: PAT_882_1677_789.png → SCC
# Copiada: PAT_1725_3222_943.png → ACK
# Copiada: PAT_98_152_562.png → BCC
# Copiada: PAT_995_1867_5.png → MEL
# Copiada: PAT_1884_3730_813.png → ACK
# Copiada: PAT_369_755_391.png → SCC
# Copiada: PAT_1276_957_406.png → NEV
# Copiada: PAT_1070_305_907.png → ACK
# Copiada: PAT_1688_3066_491.png → ACK
# Copiada: PAT_981_1848_906.png → BCC
# Copiada: PAT_409_812_974.png → BCC
# Copiada: PAT_276_425_539.png → ACK
# Copiada: PAT_430_848_476.png → BCC
# Copiada: PAT_419_832_706.png → BCC
# Copiada: PAT_1423_1472_18.png → ACK
# Copiada: PAT_55_84_506.png → BCC
# Copiada: PAT_1710_3160_488.png → ACK
# Copiada: PAT_1818_3568_132.png → ACK
# Copiada: PAT_1414_1429_59.png → ACK
# Copiada: PAT_1573_2499_849.png → ACK
# Copiada: PAT_377_1580_534.png → SCC
# Copiada: PAT_802_1516_910.png → ACK
# Copiada: PAT_962_1823_942.png → BCC
# Copiada: PAT_1109_437_254.png → NEV
# Copiada: PAT_241_367_374.png → BCC
# Copiada: PAT_1210_738_915.png → ACK
# Copiada: PAT_1492_1705_578.png → ACK
# Copiada: PAT_492_937_958.png → SCC
# Copiada: PAT_1400_1372_276.png → SEK
# Copiada: PAT_966_1825_584.png → MEL
# Copiada: PAT_181_833_109.png → ACK
# Copiada: PAT_263_404_410.png → ACK
# Copiada: PAT_549_1043_676.png → SCC
# Copiada: PAT_461_895_72.png → BCC
# Copiada: PAT_875_1669_946.png → BCC
# Copiada: PAT_1721_3219_737.png → SEK
# Copiada: PAT_714_1337_709.png → SCC
# Copiada: PAT_426_842_458.png → BCC
# Copiada: PAT_847_1610_165.png → BCC
# Copiada: PAT_281_1516_753.png → ACK
# Copiada: PAT_168_1486_97.png → BCC
# Copiada: PAT_441_861_415.png → BCC
# Copiada: PAT_958_1812_62.png → NEV
# Copiada: PAT_319_680_832.png → SCC
# Copiada: PAT_999_20_223.png → ACK
# Copiada: PAT_1305_4097_251.png → SEK
# Copiada: PAT_796_1510_130.png → BCC
# Copiada: PAT_963_1819_298.png → SCC
# Copiada: PAT_1730_3236_7.png → SEK
# Copiada: PAT_1546_1871_376.png → ACK
# Copiada: PAT_2154_4783_625.png → ACK
# Copiada: PAT_413_819_268.png → BCC
# Copiada: PAT_1414_1432_969.png → ACK
# Copiada: PAT_690_1309_981.png → BCC
# Copiada: PAT_2127_4662_596.png → NEV
# Copiada: PAT_1552_1895_190.png → ACK
# Copiada: PAT_1754_3308_390.png → NEV
# Copiada: PAT_118_180_386.png → BCC
# Copiada: PAT_850_1611_332.png → BCC
# Copiada: PAT_771_1488_562.png → SCC
# Copiada: PAT_1410_1410_46.png → ACK
# Copiada: PAT_365_751_709.png → SCC
# Copiada: PAT_63_1075_498.png → BCC
# Copiada: PAT_207_3951_140.png → ACK
# Copiada: PAT_483_925_716.png → BCC
# Copiada: PAT_358_738_837.png → BCC
# Copiada: PAT_875_1670_121.png → BCC
# Copiada: PAT_645_1300_463.png → BCC
# Copiada: PAT_514_967_300.png → BCC
# Copiada: PAT_1286_1000_517.png → SEK
# Copiada: PAT_330_698_211.png → BCC
# Copiada: PAT_1062_264_741.png → ACK
# Copiada: PAT_792_4351_858.png → ACK
# Copiada: PAT_1728_3234_299.png → ACK
# Copiada: PAT_722_1377_120.png → BCC
# Copiada: PAT_2076_4459_450.png → ACK
# Copiada: PAT_280_431_466.png → BCC
# Copiada: PAT_2008_4126_489.png → ACK
# Copiada: PAT_1411_1414_355.png → ACK
# Copiada: PAT_655_926_447.png → ACK
# Copiada: PAT_1651_2914_833.png → ACK
# Copiada: PAT_966_1825_546.png → MEL
# Copiada: PAT_396_796_394.png → BCC
# Copiada: PAT_1701_3135_5.png → SEK
# Copiada: PAT_2042_4301_636.png → NEV
# Copiada: PAT_216_331_678.png → SCC
# Copiada: PAT_747_1408_427.png → BCC
# Copiada: PAT_691_1311_686.png → BCC
# Copiada: PAT_34_47_108.png → BCC
# Copiada: PAT_1277_964_152.png → ACK
# Copiada: PAT_361_1568_456.png → SCC
# Copiada: PAT_162_252_773.png → BCC
# Copiada: PAT_1794_3435_711.png → ACK
# Copiada: PAT_1702_3548_386.png → NEV
# Copiada: PAT_267_412_275.png → BCC
# Copiada: PAT_395_795_43.png → SCC
# Copiada: PAT_465_901_627.png → NEV
# Copiada: PAT_306_1646_903.png → ACK
# Copiada: PAT_249_380_366.png → ACK
# Copiada: PAT_985_1856_397.png → BCC
# Copiada: PAT_458_891_709.png → BCC
# Copiada: PAT_747_1410_179.png → ACK
# Copiada: PAT_1316_1114_517.png → ACK
# Copiada: PAT_398_799_163.png → NEV
# Copiada: PAT_953_1806_326.png → SCC
# Copiada: PAT_466_903_893.png → BCC
# Copiada: PAT_1132_508_325.png → ACK
# Copiada: PAT_300_648_84.png → ACK
# Copiada: PAT_82_125_365.png → BCC
# Copiada: PAT_478_916_806.png → BCC
# Copiada: PAT_1089_375_677.png → NEV
# Copiada: PAT_76_1039_269.png → SCC
# Copiada: PAT_663_1254_732.png → SCC
# Copiada: PAT_206_312_760.png → BCC
# Copiada: PAT_1566_2435_150.png → ACK
# Copiada: PAT_1955_3947_778.png → ACK
# Copiada: PAT_1638_2878_536.png → ACK
# Copiada: PAT_1298_1051_831.png → NEV
# Copiada: PAT_167_258_711.png → BCC
# Copiada: PAT_54_83_405.png → BCC
# Copiada: PAT_997_14_40.png → ACK
# Copiada: PAT_373_761_708.png → BCC
# Copiada: PAT_1509_1741_810.png → SEK
# Copiada: PAT_228_348_535.png → BCC
# Copiada: PAT_1871_3666_675.png → SEK
# Copiada: PAT_547_1033_911.png → BCC
# Copiada: PAT_1582_2574_890.png → SEK
# Copiada: PAT_56_86_479.png → SCC
# Copiada: PAT_699_1320_901.png → BCC
# Copiada: PAT_221_339_566.png → BCC
# Copiada: PAT_803_1522_907.png → BCC
# Copiada: PAT_256_295_583.png → SEK
# Copiada: PAT_115_175_206.png → BCC
# Copiada: PAT_759_1433_973.png → NEV
# Copiada: PAT_782_1493_140.png → ACK
# Copiada: PAT_1942_3915_388.png → SEK
# Copiada: PAT_1125_492_523.png → ACK
# Copiada: PAT_256_394_449.png → BCC
# Copiada: PAT_385_783_574.png → BCC
# Copiada: PAT_721_1365_142.png → BCC
# Copiada: PAT_940_1774_962.png → SCC
# Copiada: PAT_316_674_924.png → BCC
# Copiada: PAT_243_372_119.png → BCC
# Copiada: PAT_1094_381_446.png → ACK
# Copiada: PAT_412_818_61.png → ACK
# Copiada: PAT_359_740_46.png → BCC
# Copiada: PAT_842_1606_720.png → BCC
# Copiada: PAT_1082_342_705.png → ACK
# Copiada: PAT_1821_3575_920.png → ACK
# Copiada: PAT_526_991_109.png → BCC
# Copiada: PAT_1460_1598_959.png → SEK
# Copiada: PAT_15_1001_749.png → BCC
# Copiada: PAT_1547_1874_432.png → ACK
# Copiada: PAT_880_1673_410.png → ACK
# Copiada: PAT_730_1383_535.png → BCC
# Copiada: PAT_948_1801_993.png → BCC
# Copiada: PAT_962_1823_857.png → BCC
# Copiada: PAT_21_982_266.png → BCC
# Copiada: PAT_839_1591_204.png → NEV
# Copiada: PAT_257_395_866.png → BCC
# Copiada: PAT_1217_762_198.png → NEV
# Copiada: PAT_397_798_482.png → SCC
# Copiada: PAT_1481_1674_735.png → ACK
# Copiada: PAT_665_1262_774.png → NEV
# Copiada: PAT_976_1837_861.png → BCC
# Copiada: PAT_827_1600_1000.png → BCC
# Copiada: PAT_1764_3335_366.png → SEK
# Copiada: PAT_645_1223_124.png → BCC
# Copiada: PAT_185_285_862.png → BCC
# Copiada: PAT_1333_1177_261.png → NEV
# Copiada: PAT_1461_1600_867.png → SEK
# Copiada: PAT_1658_2933_322.png → NEV
# Copiada: PAT_1013_82_876.png → ACK
# Copiada: PAT_2066_4417_201.png → SEK
# Copiada: PAT_1027_128_854.png → ACK
# Copiada: PAT_1307_1092_878.png → ACK
# Copiada: PAT_1593_2651_122.png → ACK
# Copiada: PAT_375_763_732.png → BCC
# Copiada: PAT_302_1633_845.png → ACK
# Copiada: PAT_495_941_26.png → MEL
# Copiada: PAT_535_1012_145.png → BCC
# Copiada: PAT_1583_2607_628.png → SEK
# Copiada: PAT_121_184_502.png → BCC
# Copiada: PAT_614_1166_885.png → MEL
# Copiada: PAT_524_987_738.png → BCC
# Copiada: PAT_381_775_566.png → BCC
# Copiada: PAT_1774_3352_474.png → ACK
# Copiada: PAT_375_763_980.png → BCC
# Copiada: PAT_79_120_739.png → BCC
# Copiada: PAT_587_3431_6.png → ACK
# Copiada: PAT_666_1268_870.png → BCC
# Copiada: PAT_691_3994_671.png → ACK
# Copiada: PAT_364_749_377.png → BCC
# Copiada: PAT_576_1089_435.png → BCC
# Copiada: PAT_952_1807_58.png → BCC
# Copiada: PAT_1128_497_322.png → ACK
# Copiada: PAT_485_928_796.png → BCC
# Copiada: PAT_39_55_233.png → BCC
# Copiada: PAT_340_714_68.png → MEL
# Copiada: PAT_1981_4023_673.png → ACK
# Copiada: PAT_315_673_227.png → BCC
# Copiada: PAT_1071_313_789.png → ACK
# Copiada: PAT_59_94_849.png → ACK
# Copiada: PAT_338_710_319.png → SCC
# Copiada: PAT_1324_1145_309.png → ACK
# Copiada: PAT_1914_3822_863.png → SEK
# Copiada: PAT_672_1272_705.png → NEV
# Copiada: PAT_2122_4642_680.png → ACK
# Copiada: PAT_886_1684_297.png → ACK
# Copiada: PAT_93_361_203.png → SEK
# Copiada: PAT_270_1386_755.png → ACK
# Copiada: PAT_908_1726_939.png → SCC
# Copiada: PAT_666_1271_645.png → BCC
# Copiada: PAT_115_1138_870.png → MEL
# Copiada: PAT_585_1130_474.png → ACK
# Copiada: PAT_464_1794_78.png → BCC
# Copiada: PAT_380_773_542.png → BCC
# Copiada: PAT_587_1117_880.png → BCC
# Copiada: PAT_1665_2978_578.png → ACK
# Copiada: PAT_500_947_77.png → SCC
# Copiada: PAT_2011_4140_988.png → ACK
# Copiada: PAT_600_1141_542.png → SCC
# Copiada: PAT_1661_2956_357.png → ACK
# Copiada: PAT_1428_1489_38.png → ACK
# Copiada: PAT_1682_3050_600.png → SEK
# Copiada: PAT_832_1569_413.png → BCC
# Copiada: PAT_131_197_974.png → SCC
# Copiada: PAT_270_1382_561.png → SEK
# Copiada: PAT_170_264_785.png → BCC
# Copiada: PAT_1364_1246_420.png → NEV
# Copiada: PAT_192_295_164.png → BCC
# Copiada: PAT_93_142_269.png → SCC
# Copiada: PAT_831_1570_991.png → ACK
# Copiada: PAT_840_1595_981.png → BCC
# Copiada: PAT_792_1498_936.png → ACK
# Copiada: PAT_2155_4784_483.png → SEK
# Copiada: PAT_291_446_704.png → BCC
# Copiada: PAT_1392_1353_161.png → ACK
# Copiada: PAT_551_1047_567.png → BCC
# Copiada: PAT_939_1791_329.png → SEK
# Copiada: PAT_1057_242_297.png → ACK
# Copiada: PAT_1760_3326_525.png → ACK
# Copiada: PAT_346_720_265.png → BCC
# Copiada: PAT_259_399_801.png → SCC
# Copiada: PAT_838_1587_73.png → BCC
# Copiada: PAT_738_1397_966.png → BCC
# Copiada: PAT_728_1533_952.png → ACK
# Copiada: PAT_372_760_267.png → BCC
# Copiada: PAT_1922_3848_451.png → SEK
# Copiada: PAT_286_1458_381.png → ACK
# Copiada: PAT_161_250_338.png → BCC
# Copiada: PAT_349_724_750.png → SCC
# Copiada: PAT_522_986_305.png → BCC
# Copiada: PAT_793_1512_513.png → NEV
# Copiada: PAT_462_896_893.png → BCC
# Copiada: PAT_895_1699_872.png → MEL
# Copiada: PAT_545_1030_854.png → BCC
# Copiada: PAT_145_216_158.png → BCC
# Copiada: PAT_214_329_70.png → BCC
# Copiada: PAT_1124_489_151.png → ACK
# Copiada: PAT_513_964_343.png → BCC
# Copiada: PAT_439_859_283.png → NEV
# Copiada: PAT_108_162_660.png → ACK
# Copiada: PAT_1031_148_29.png → ACK
# Copiada: PAT_1826_3580_871.png → SEK
# Copiada: PAT_354_1817_500.png → SEK
# Copiada: PAT_1619_2774_616.png → SEK
# Copiada: PAT_1993_4076_174.png → ACK
# Copiada: PAT_1729_3235_909.png → ACK
# Copiada: PAT_1145_534_524.png → ACK
# Copiada: PAT_510_959_174.png → BCC
# Copiada: PAT_974_1841_693.png → BCC
# Copiada: PAT_580_1104_684.png → BCC
# Copiada: PAT_207_313_709.png → BCC
# Copiada: PAT_1945_3923_428.png → NEV
# Copiada: PAT_1875_3689_646.png → ACK
# Copiada: PAT_935_1781_341.png → BCC
# Copiada: PAT_493_3016_512.png → ACK
# Copiada: PAT_177_275_905.png → BCC
# Copiada: PAT_2157_4789_969.png → ACK
# Copiada: PAT_631_1227_585.png → BCC
# Copiada: PAT_1393_1355_270.png → ACK
# Copiada: PAT_2010_4136_318.png → ACK
# Copiada: PAT_806_1520_708.png → BCC
# Copiada: PAT_923_1753_706.png → BCC
# Copiada: PAT_497_943_580.png → SCC
# Copiada: PAT_1334_1178_413.png → NEV
# Copiada: PAT_521_984_412.png → BCC
# Copiada: PAT_2125_4653_497.png → NEV
# Copiada: PAT_771_1491_390.png → BCC
# Copiada: PAT_1256_879_199.png → NEV
# Copiada: PAT_2009_4134_828.png → ACK
# Copiada: PAT_679_1286_677.png → SCC
# Copiada: PAT_1976_4000_701.png → ACK
# Copiada: PAT_879_1676_668.png → BCC
# Copiada: PAT_561_1069_418.png → SCC
# Copiada: PAT_757_1431_696.png → ACK
# Copiada: PAT_731_1387_634.png → ACK
# Copiada: PAT_372_760_355.png → BCC
# Copiada: PAT_770_1451_136.png → SCC
# Copiada: PAT_74_112_729.png → BCC
# Copiada: PAT_1472_1639_87.png → ACK
# Copiada: PAT_354_731_155.png → BCC
# Copiada: PAT_1257_887_828.png → NEV
# Copiada: PAT_2048_4333_63.png → SEK
# Copiada: PAT_1304_3507_308.png → NEV
# Copiada: PAT_425_841_644.png → NEV
# Copiada: PAT_330_1438_323.png → BCC
# Copiada: PAT_264_405_118.png → BCC
# Copiada: PAT_1881_3711_217.png → ACK
# Copiada: PAT_1818_3570_577.png → ACK
# Copiada: PAT_128_194_144.png → BCC
# Copiada: PAT_666_1269_65.png → BCC
# Copiada: PAT_1554_4170_992.png → SEK
# Copiada: PAT_307_659_85.png → SCC
# Copiada: PAT_1139_523_682.png → ACK
# Copiada: PAT_106_158_249.png → BCC
# Copiada: PAT_1063_269_755.png → ACK
# Copiada: PAT_817_1537_643.png → BCC
# Copiada: PAT_255_388_77.png → BCC
# Copiada: PAT_390_790_505.png → SCC
# Copiada: PAT_1068_285_845.png → SEK
# Copiada: PAT_1947_3926_165.png → NEV
# Copiada: PAT_92_141_551.png → ACK
# Copiada: PAT_1733_3239_934.png → NEV
# Copiada: PAT_531_1004_189.png → BCC
# Copiada: PAT_1364_1246_927.png → NEV
# Copiada: PAT_981_1848_486.png → BCC
# Copiada: PAT_1402_1377_959.png → ACK
# Copiada: PAT_233_354_935.png → MEL
# Copiada: PAT_1042_187_746.png → ACK
# Copiada: PAT_1813_3562_195.png → SEK
# Copiada: PAT_1141_526_416.png → ACK
# Copiada: PAT_689_1306_772.png → SCC
# Copiada: PAT_1769_3342_63.png → ACK
# Copiada: PAT_853_1642_497.png → BCC
# Copiada: PAT_108_161_423.png → SCC
# Copiada: PAT_1956_3949_217.png → SEK
# Copiada: PAT_1476_1657_788.png → ACK
# Copiada: PAT_1109_436_141.png → NEV
# Copiada: PAT_211_319_777.png → BCC
# Copiada: PAT_1393_1356_371.png → SEK
# Copiada: PAT_319_679_533.png → BCC
# Copiada: PAT_766_1444_52.png → BCC
# Copiada: PAT_408_811_808.png → ACK
# Copiada: PAT_1639_2879_744.png → NEV
# Copiada: PAT_645_1222_140.png → BCC
# Copiada: PAT_179_278_331.png → BCC
# Copiada: PAT_726_1371_543.png → BCC
# Copiada: PAT_82_125_525.png → BCC
# Copiada: PAT_975_4734_783.png → NEV
# Copiada: PAT_109_868_723.png → MEL
# Copiada: PAT_286_1459_926.png → NEV
# Copiada: PAT_851_4519_488.png → ACK
# Copiada: PAT_1243_836_47.png → ACK
# Copiada: PAT_1329_1168_620.png → SEK
# Copiada: PAT_115_176_455.png → BCC
# Copiada: PAT_1439_1521_868.png → ACK
# Copiada: PAT_2043_4308_681.png → ACK
# Copiada: PAT_827_1599_248.png → BCC
# Copiada: PAT_1181_659_231.png → ACK
# Copiada: PAT_1326_1156_139.png → NEV
# Copiada: PAT_1074_322_174.png → ACK
# Copiada: PAT_503_949_409.png → SCC
# Copiada: PAT_691_1310_780.png → BCC
# Copiada: PAT_514_967_908.png → BCC
# Copiada: PAT_217_333_61.png → BCC
# Copiada: PAT_467_904_235.png → BCC
# Copiada: PAT_101_1041_651.png → BCC
# Copiada: PAT_1347_1226_928.png → ACK
# Copiada: PAT_2050_4350_36.png → ACK
# Copiada: PAT_73_111_435.png → BCC
# Copiada: PAT_858_1633_926.png → BCC
# Copiada: PAT_652_1231_516.png → BCC
# Copiada: PAT_115_175_283.png → BCC
# Copiada: PAT_1330_1172_722.png → NEV
# Copiada: PAT_2061_4395_587.png → ACK
# Copiada: PAT_1374_1286_939.png → ACK
# Copiada: PAT_930_1760_560.png → BCC
# Copiada: PAT_2071_4433_848.png → ACK
# Copiada: PAT_673_3928_888.png → ACK
# Copiada: PAT_597_1139_181.png → BCC
# Copiada: PAT_999_20_540.png → ACK
# Copiada: PAT_1762_3332_245.png → ACK
# Copiada: PAT_235_360_50.png → BCC
# Copiada: PAT_1070_304_845.png → ACK
# Copiada: PAT_490_933_352.png → SCC
# Copiada: PAT_304_4186_458.png → ACK
# Copiada: PAT_655_1245_807.png → SCC
# Copiada: PAT_1652_2915_65.png → SEK
# Copiada: PAT_1397_1361_183.png → SEK
# Copiada: PAT_2143_4736_227.png → ACK
# Copiada: PAT_1526_1792_482.png → ACK
# Copiada: PAT_38_1002_34.png → BCC
# Copiada: PAT_677_1349_541.png → SCC
# Copiada: PAT_191_294_629.png → BCC
# Copiada: PAT_171_265_757.png → BCC
# Copiada: PAT_801_1518_78.png → MEL
# Copiada: PAT_333_1468_620.png → NEV
# Copiada: PAT_1145_534_529.png → ACK
# Copiada: PAT_354_1814_726.png → SEK
# Copiada: PAT_1588_2629_296.png → NEV
# Copiada: PAT_224_1340_551.png → ACK
# Copiada: PAT_1550_1886_849.png → ACK
# Copiada: PAT_397_797_742.png → SCC
# Copiada: PAT_289_442_43.png → ACK
# Copiada: PAT_1035_165_800.png → ACK
# Copiada: PAT_87_133_391.png → SEK
# Copiada: PAT_46_879_225.png → BCC
# Copiada: PAT_654_1244_16.png → BCC
# Copiada: PAT_996_6_886.png → ACK
# Copiada: PAT_1036_169_687.png → ACK
# Copiada: PAT_1350_1230_878.png → NEV
# Copiada: PAT_63_98_187.png → BCC
# Copiada: PAT_90_219_648.png → SEK
# Copiada: PAT_1122_479_664.png → SEK
# Copiada: PAT_378_770_302.png → BCC
# Copiada: PAT_1648_2904_523.png → NEV
# Copiada: PAT_194_298_945.png → SEK
# Copiada: PAT_1265_908_754.png → ACK
# Copiada: PAT_108_162_526.png → ACK
# Copiada: PAT_381_775_253.png → BCC
# Copiada: PAT_1197_713_520.png → NEV
# Copiada: PAT_2016_4160_868.png → SEK
# Copiada: PAT_467_904_776.png → BCC
# Copiada: PAT_723_1396_338.png → BCC
# Copiada: PAT_1866_3660_115.png → ACK
# Copiada: PAT_753_1427_658.png → ACK
# Copiada: PAT_1719_3203_18.png → SEK
# Copiada: PAT_279_429_142.png → BCC
# Copiada: PAT_1329_1167_230.png → SEK
# Copiada: PAT_539_1023_878.png → ACK
# Copiada: PAT_1903_3791_14.png → NEV
# Copiada: PAT_1215_752_707.png → NEV
# Copiada: PAT_270_416_398.png → BCC
# Copiada: PAT_179_277_436.png → BCC
# Copiada: PAT_974_1842_574.png → SCC
# Copiada: PAT_35_48_43.png → BCC
# Copiada: PAT_527_1359_165.png → SCC
# Copiada: PAT_319_680_166.png → SCC
# Copiada: PAT_1112_455_845.png → ACK
# Copiada: PAT_1715_3186_948.png → ACK
# Copiada: PAT_1369_1269_370.png → ACK
# Copiada: PAT_301_649_533.png → BCC
# Copiada: PAT_247_1293_449.png → BCC
# Copiada: PAT_645_1224_768.png → BCC
# Copiada: PAT_995_1867_165.png → MEL
# Copiada: PAT_416_826_123.png → BCC
# Copiada: PAT_1014_85_22.png → ACK
# Copiada: PAT_872_1707_638.png → BCC
# Copiada: PAT_919_1744_318.png → BCC
# Copiada: PAT_858_1631_427.png → BCC
# Copiada: PAT_1971_3984_534.png → SEK
# Copiada: PAT_822_1550_826.png → BCC
# Copiada: PAT_38_1003_68.png → ACK
# Copiada: PAT_20_30_44.png → SCC
# Copiada: PAT_48_74_402.png → SCC
# Copiada: PAT_112_168_360.png → BCC
# Copiada: PAT_388_1590_518.png → BCC
# Copiada: PAT_746_1407_708.png → MEL
# Copiada: PAT_65_101_847.png → ACK
# Copiada: PAT_69_1053_540.png → ACK
# Copiada: PAT_1119_472_513.png → ACK
# Copiada: PAT_517_972_845.png → BCC
# Copiada: PAT_44_63_151.png → ACK
# Copiada: PAT_2126_4654_644.png → ACK
# Copiada: PAT_712_1335_359.png → SCC
# Copiada: PAT_1849_3629_214.png → ACK
# Copiada: PAT_708_1333_222.png → BCC
# Copiada: PAT_860_1641_440.png → SCC
# Copiada: PAT_1420_1460_733.png → SEK
# Copiada: PAT_2065_4413_298.png → SEK
# Copiada: PAT_882_1678_192.png → SCC
# Copiada: PAT_532_3216_633.png → SEK
# Copiada: PAT_394_794_235.png → BCC
# Copiada: PAT_590_1121_504.png → SCC
# Copiada: PAT_1933_3883_413.png → SEK
# Copiada: PAT_1565_2432_808.png → ACK
# Copiada: PAT_1904_3794_215.png → NEV
# Copiada: PAT_279_1393_118.png → BCC
# Copiada: PAT_211_319_810.png → BCC
# Copiada: PAT_864_1645_639.png → BCC
# Copiada: PAT_1783_3415_640.png → SEK
# Copiada: PAT_1699_3126_673.png → NEV
# Copiada: PAT_1364_1246_447.png → NEV
# Copiada: PAT_512_962_998.png → BCC
# Copiada: PAT_924_1757_784.png → SCC
# Copiada: PAT_809_1528_118.png → ACK
# Copiada: PAT_1483_1678_850.png → ACK
# Copiada: PAT_400_801_376.png → SCC
# Copiada: PAT_2102_4575_616.png → ACK
# Copiada: PAT_326_690_797.png → BCC
# Copiada: PAT_40_1026_312.png → BCC
# Copiada: PAT_957_1814_77.png → NEV
# Copiada: PAT_452_882_896.png → BCC
# Copiada: PAT_948_1801_721.png → BCC
# Copiada: PAT_57_90_910.png → ACK
# Copiada: PAT_975_1834_152.png → MEL
# Copiada: PAT_128_194_28.png → BCC
# Copiada: PAT_155_240_211.png → SCC
# Copiada: PAT_2107_4595_381.png → ACK
# Copiada: PAT_53_82_940.png → BCC
# Copiada: PAT_596_1146_316.png → BCC
# Copiada: PAT_713_1336_159.png → SCC
# Copiada: PAT_153_1200_541.png → BCC
# Copiada: PAT_1874_3687_799.png → SEK
# Copiada: PAT_230_351_720.png → ACK
# Copiada: PAT_328_1738_890.png → ACK
# Copiada: PAT_1498_1716_626.png → ACK
# Copiada: PAT_366_752_782.png → BCC
# Copiada: PAT_433_852_20.png → MEL
# Copiada: PAT_1709_3159_935.png → SEK
# Copiada: PAT_431_850_472.png → BCC
# Copiada: PAT_1611_2725_680.png → NEV
# Copiada: PAT_849_1612_143.png → BCC
# Copiada: PAT_1399_1367_121.png → ACK
# Copiada: PAT_1704_3142_702.png → ACK
# Copiada: PAT_227_347_19.png → SCC
# Copiada: PAT_1799_3457_209.png → ACK
# Copiada: PAT_430_847_315.png → BCC
# Copiada: PAT_903_1719_943.png → BCC
# Copiada: PAT_749_1414_770.png → ACK
# Copiada: PAT_1065_277_768.png → ACK
# Copiada: PAT_202_307_424.png → BCC
# Copiada: PAT_1812_3492_670.png → ACK
# Copiada: PAT_1554_2393_96.png → SEK
# Copiada: PAT_1369_1270_496.png → ACK
# Copiada: PAT_761_1435_561.png → BCC
# Copiada: PAT_1738_3260_304.png → ACK
# Copiada: PAT_1019_110_194.png → ACK
# Copiada: PAT_49_75_326.png → SCC
# Copiada: PAT_999_20_583.png → ACK
# Copiada: PAT_1733_3239_389.png → NEV
# Copiada: PAT_247_378_484.png → BCC
# Copiada: PAT_456_887_499.png → BCC
# Copiada: PAT_637_1434_570.png → SCC
# Copiada: PAT_571_1097_652.png → ACK
# Copiada: PAT_1198_715_648.png → SEK
# Copiada: PAT_1731_3237_197.png → NEV
# Copiada: PAT_1593_2652_422.png → SEK
# Copiada: PAT_388_2452_548.png → ACK
# Copiada: PAT_202_916_612.png → ACK
# Copiada: PAT_1170_608_367.png → ACK
# Copiada: PAT_1065_275_136.png → ACK
# Copiada: PAT_704_1323_974.png → ACK
# Copiada: PAT_753_1428_451.png → BCC
# Copiada: PAT_715_4072_827.png → ACK
# Copiada: PAT_639_3674_452.png → ACK
# Copiada: PAT_1072_318_856.png → SEK
# Copiada: PAT_349_724_133.png → SCC
# Copiada: PAT_1420_1461_93.png → SEK
# Copiada: PAT_237_362_909.png → BCC
# Copiada: PAT_646_1225_590.png → BCC
# Copiada: PAT_630_1196_710.png → SCC
# Copiada: PAT_2041_4298_408.png → ACK
# Copiada: PAT_1600_2685_445.png → ACK
# Copiada: PAT_1460_1598_708.png → SEK
# Copiada: PAT_2131_4683_112.png → ACK
# Copiada: PAT_492_1782_752.png → ACK
# Copiada: PAT_757_4220_942.png → ACK
# Copiada: PAT_412_817_232.png → BCC
# Copiada: PAT_1070_308_751.png → SEK
# Copiada: PAT_365_750_854.png → SCC
# Copiada: PAT_2011_4140_787.png → ACK
# Copiada: PAT_330_696_894.png → BCC
# Copiada: PAT_582_1363_358.png → BCC
# Copiada: PAT_1280_972_727.png → ACK
# Copiada: PAT_393_793_852.png → ACK
# Copiada: PAT_61_299_74.png → NEV
# Copiada: PAT_432_851_560.png → BCC
# Copiada: PAT_2106_4590_227.png → ACK
# Copiada: PAT_85_129_225.png → ACK
# Copiada: PAT_1790_3427_355.png → ACK
# Copiada: PAT_180_279_377.png → BCC
# Copiada: PAT_219_336_376.png → SCC
# Copiada: PAT_1286_999_824.png → SEK
# Copiada: PAT_529_994_419.png → BCC
# Copiada: PAT_188_289_908.png → BCC
# Copiada: PAT_356_736_188.png → BCC
# Copiada: PAT_1432_1497_328.png → ACK
# Copiada: PAT_951_1836_991.png → ACK
# Copiada: PAT_1448_1551_366.png → NEV
# Copiada: PAT_911_1728_101.png → BCC
# Copiada: PAT_697_1317_892.png → BCC
# Copiada: PAT_1832_3597_594.png → SEK
# Copiada: PAT_856_1626_523.png → BCC
# Copiada: PAT_1914_3821_427.png → NEV
# Copiada: PAT_835_1577_938.png → BCC
# Copiada: PAT_1914_3823_180.png → NEV
# Copiada: PAT_1978_4004_82.png → SEK
# Copiada: PAT_627_1188_755.png → NEV
# Copiada: PAT_531_3079_652.png → ACK
# Copiada: PAT_1720_3208_130.png → ACK
# Copiada: PAT_115_177_575.png → BCC
# Copiada: PAT_570_1085_429.png → BCC
# Copiada: PAT_337_706_254.png → BCC
# Copiada: PAT_1597_2666_130.png → NEV
# Copiada: PAT_923_1753_496.png → BCC
# Copiada: PAT_1682_3052_873.png → NEV
# Copiada: PAT_207_1280_15.png → BCC
# Copiada: PAT_242_368_261.png → BCC
# Copiada: PAT_806_1519_527.png → BCC
# Copiada: PAT_1491_1703_637.png → ACK
# Copiada: PAT_1379_4145_486.png → NEV
# Copiada: PAT_703_1329_112.png → BCC
# Copiada: PAT_468_905_765.png → BCC
# Copiada: PAT_1449_1554_932.png → ACK
# Copiada: PAT_1666_2985_968.png → ACK
# Copiada: PAT_305_655_30.png → BCC
# Copiada: PAT_493_1862_360.png → BCC
# Copiada: PAT_401_4594_970.png → ACK
# Copiada: PAT_36_49_935.png → BCC
# Copiada: PAT_204_310_975.png → BCC
# Copiada: PAT_788_1503_168.png → BCC
# Copiada: PAT_217_963_806.png → ACK
# Copiada: PAT_1298_1050_519.png → NEV
# Copiada: PAT_514_969_187.png → BCC
# Copiada: PAT_86_1109_306.png → BCC
# Copiada: PAT_1585_2619_396.png → SEK
# Copiada: PAT_812_1625_430.png → BCC
# Copiada: PAT_86_1082_41.png → ACK
# Copiada: PAT_886_4635_304.png → ACK
# Copiada: PAT_1451_1562_545.png → NEV
# Copiada: PAT_791_1487_906.png → NEV
# Copiada: PAT_223_341_187.png → BCC
# Copiada: PAT_267_1061_152.png → BCC
# Copiada: PAT_1314_1108_442.png → SEK
# Copiada: PAT_15_23_240.png → BCC
# Copiada: PAT_2006_4123_719.png → NEV
# Copiada: PAT_196_300_749.png → BCC
# Copiada: PAT_499_945_878.png → BCC
# Copiada: PAT_1575_2516_23.png → ACK
# Copiada: PAT_230_1008_673.png → ACK
# Copiada: PAT_470_908_103.png → BCC
# Copiada: PAT_1403_1392_407.png → ACK
# Copiada: PAT_813_1619_543.png → BCC
# Copiada: PAT_905_1721_327.png → BCC
# Copiada: PAT_294_638_564.png → BCC
# Copiada: PAT_621_1182_456.png → NEV
# Copiada: PAT_220_1343_489.png → NEV
# Copiada: PAT_1460_1598_746.png → SEK
# Copiada: PAT_537_1014_961.png → SCC
# Copiada: PAT_388_4500_67.png → ACK
# Copiada: PAT_311_666_191.png → SCC
# Copiada: PAT_382_776_986.png → BCC
# Copiada: PAT_735_1391_683.png → ACK
# Copiada: PAT_221_339_951.png → BCC
# Copiada: PAT_1591_2648_855.png → NEV
# Copiada: PAT_286_1459_666.png → NEV
# Copiada: PAT_1065_278_954.png → ACK
# Copiada: PAT_924_1757_704.png → SCC
# Copiada: PAT_846_1607_895.png → ACK
# Copiada: PAT_168_262_74.png → BCC
# Copiada: PAT_1171_615_468.png → ACK
# Copiada: PAT_1477_1660_226.png → NEV
# Copiada: PAT_776_1466_241.png → BCC
# Copiada: PAT_356_735_568.png → BCC
# Copiada: PAT_109_868_113.png → MEL
# Copiada: PAT_755_1430_681.png → ACK
# Copiada: PAT_549_1043_36.png → SCC
# Copiada: PAT_917_1735_936.png → NEV
# Copiada: PAT_1074_322_242.png → ACK
# Copiada: PAT_2034_4268_141.png → ACK
# Copiada: PAT_8_15_820.png → BCC
# Copiada: PAT_86_1109_164.png → BCC
# Copiada: PAT_540_1016_644.png → BCC
# Copiada: PAT_166_3672_759.png → SEK
# Copiada: PAT_749_1415_164.png → ACK
# Copiada: PAT_1402_1377_799.png → ACK
# Copiada: PAT_1479_1669_376.png → ACK
# Copiada: PAT_744_1405_742.png → BCC
# Copiada: PAT_1942_3917_379.png → SEK
# Copiada: PAT_677_1349_851.png → SCC
# Copiada: PAT_71_108_56.png → ACK
# Copiada: PAT_337_706_944.png → BCC
# Copiada: PAT_388_787_818.png → BCC
# Copiada: PAT_287_440_729.png → ACK
# Copiada: PAT_1764_3335_803.png → SEK
# Copiada: PAT_771_1489_345.png → SCC
# Copiada: PAT_814_1532_265.png → BCC
# Copiada: PAT_2021_4180_381.png → ACK
# Copiada: PAT_419_2768_910.png → SEK
# Copiada: PAT_664_1263_781.png → SCC
# Copiada: PAT_1591_2648_723.png → NEV
# Copiada: PAT_1641_2886_284.png → SEK
# Copiada: PAT_1322_1137_201.png → ACK
# Copiada: PAT_413_819_550.png → BCC
# Copiada: PAT_1404_1393_540.png → SEK
# Copiada: PAT_253_384_607.png → BCC
# Copiada: PAT_837_1582_714.png → BCC
# Copiada: PAT_522_986_800.png → BCC
# Copiada: PAT_53_1370_288.png → BCC
# Copiada: PAT_938_1789_693.png → BCC
# Copiada: PAT_854_1635_103.png → BCC
# Copiada: PAT_1690_3082_117.png → ACK
# Copiada: PAT_595_1142_142.png → ACK
# Copiada: PAT_1993_4077_139.png → ACK
# Copiada: PAT_835_1578_592.png → BCC
# Copiada: PAT_492_1784_50.png → ACK
# Copiada: PAT_492_4723_890.png → ACK
# Copiada: PAT_528_992_124.png → ACK
# Copiada: PAT_709_1331_253.png → BCC
# Copiada: PAT_1392_1352_778.png → SEK
# Copiada: PAT_1547_4232_115.png → ACK
# Copiada: PAT_184_284_721.png → ACK
# Copiada: PAT_640_1210_293.png → BCC
# Copiada: PAT_1067_284_533.png → ACK
# Copiada: PAT_354_1814_619.png → SEK
# Copiada: PAT_1708_3153_799.png → ACK
# Copiada: PAT_224_1340_142.png → ACK
# Copiada: PAT_198_302_44.png → BCC
# Copiada: PAT_407_810_390.png → BCC
# Copiada: PAT_63_99_189.png → BCC
# Copiada: PAT_138_205_296.png → BCC
# Copiada: PAT_90_138_369.png → BCC
# Copiada: PAT_297_4307_924.png → NEV
# Copiada: PAT_1439_1522_211.png → SEK
# Copiada: PAT_705_1326_82.png → SCC
# Copiada: PAT_1805_3477_772.png → ACK
# Copiada: PAT_1273_953_510.png → NEV
# Copiada: PAT_715_4073_115.png → ACK
# Copiada: PAT_1572_2495_335.png → ACK
# Copiada: PAT_68_105_871.png → BCC
# Copiada: PAT_577_1107_61.png → NEV
# Copiada: PAT_1506_1735_733.png → ACK
# Copiada: PAT_154_237_625.png → BCC
# Copiada: PAT_1252_866_852.png → SEK
# Copiada: PAT_1689_3075_38.png → ACK
# Copiada: PAT_1415_1439_295.png → ACK
# Copiada: PAT_63_99_736.png → BCC
# Copiada: PAT_464_899_646.png → BCC
# Copiada: PAT_330_695_90.png → BCC
# Copiada: PAT_1707_3148_835.png → ACK
# Copiada: PAT_181_832_158.png → SEK
# Copiada: PAT_961_1818_992.png → ACK
# Copiada: PAT_126_191_304.png → BCC
# Copiada: PAT_683_1296_237.png → BCC
# Copiada: PAT_108_424_944.png → ACK
# Copiada: PAT_558_1072_486.png → BCC
# Copiada: PAT_834_4490_317.png → ACK
# Copiada: PAT_1503_1728_65.png → NEV
# Copiada: PAT_927_1759_749.png → BCC
# Copiada: PAT_97_151_503.png → BCC
# Copiada: PAT_876_1664_579.png → BCC
# Copiada: PAT_690_1309_217.png → BCC
# Copiada: PAT_122_185_957.png → BCC
# Copiada: PAT_1881_3717_785.png → NEV
# Copiada: PAT_884_1683_538.png → MEL
# Copiada: PAT_2011_4141_862.png → ACK
# Copiada: PAT_463_897_440.png → BCC
# Copiada: PAT_824_1561_796.png → ACK
# Copiada: PAT_1586_2624_615.png → SEK
# Copiada: PAT_859_1638_598.png → SCC
# Copiada: PAT_535_1011_567.png → BCC
# Copiada: PAT_793_1512_382.png → NEV
# Copiada: PAT_153_233_45.png → BCC
# Copiada: PAT_1736_3246_166.png → ACK
# Copiada: PAT_338_709_306.png → SCC
# Copiada: PAT_950_1804_64.png → BCC
# Copiada: PAT_246_377_159.png → ACK
# Copiada: PAT_796_1509_459.png → BCC
# Copiada: PAT_1608_2720_196.png → ACK
# Copiada: PAT_819_1541_727.png → SEK
# Copiada: PAT_621_3591_171.png → NEV
# Copiada: PAT_16_24_691.png → BCC
# Copiada: PAT_834_1572_973.png → SCC
# Copiada: PAT_72_110_647.png → NEV
# Copiada: PAT_152_230_934.png → BCC
# Copiada: PAT_356_4511_960.png → ACK
# Copiada: PAT_1388_3513_146.png → NEV
# Copiada: PAT_1406_1397_669.png → ACK
# Copiada: PAT_75_114_73.png → BCC
# Copiada: PAT_50_76_296.png → BCC
# Copiada: PAT_600_1141_988.png → SCC
# Copiada: PAT_624_1180_803.png → BCC
# Copiada: PAT_691_1311_2.png → BCC
# Copiada: PAT_1770_3344_274.png → NEV
# Copiada: PAT_362_744_283.png → BCC
# Copiada: PAT_198_853_778.png → NEV
# Copiada: PAT_649_1233_229.png → SEK
# Copiada: PAT_386_1554_362.png → BCC
# Copiada: PAT_641_1211_321.png → NEV
# Copiada: PAT_966_1826_587.png → ACK
# Copiada: PAT_1521_1778_763.png → SEK
# Copiada: PAT_800_1514_512.png → SCC
# Copiada: PAT_1618_2771_628.png → SEK
# Copiada: PAT_601_1147_943.png → BCC
# Copiada: PAT_994_1866_913.png → BCC
# Copiada: PAT_277_426_825.png → SCC
# Copiada: PAT_557_1058_309.png → BCC
# Copiada: PAT_67_104_730.png → BCC
# Copiada: PAT_403_804_994.png → NEV
# Copiada: PAT_465_901_106.png → NEV
# Copiada: PAT_526_3205_611.png → ACK
# Copiada: PAT_1414_1431_754.png → ACK
# Copiada: PAT_1130_501_181.png → ACK
# Copiada: PAT_841_1603_667.png → BCC
# Copiada: PAT_1022_115_132.png → ACK
# Copiada: PAT_1020_111_593.png → ACK
# Copiada: PAT_1709_3159_144.png → SEK
# Copiada: PAT_1735_3242_27.png → NEV
# Copiada: PAT_926_1758_714.png → BCC
# Copiada: PAT_154_235_162.png → BCC
# Copiada: PAT_831_1570_637.png → ACK
# Copiada: PAT_1249_862_658.png → NEV
# Copiada: PAT_759_1433_914.png → NEV
# Copiada: PAT_183_283_602.png → SCC
# Copiada: PAT_764_1448_499.png → BCC
# Copiada: PAT_934_1778_140.png → SCC
# Copiada: PAT_1531_1800_683.png → ACK
# Copiada: PAT_2144_4738_120.png → NEV
# Copiada: PAT_1370_1274_515.png → ACK
# Copiada: PAT_251_382_164.png → BCC
# Copiada: PAT_862_1643_386.png → ACK
# Copiada: PAT_1418_1447_360.png → SEK
# Copiada: PAT_56_86_802.png → SCC
# Copiada: PAT_2103_4581_72.png → NEV
# Copiada: PAT_1846_3622_35.png → NEV
# Copiada: PAT_1365_1253_912.png → ACK
# Copiada: PAT_1509_1742_422.png → ACK
# Copiada: PAT_625_1184_994.png → SEK
# Copiada: PAT_522_985_991.png → ACK
# Copiada: PAT_43_1017_483.png → BCC
# Copiada: PAT_1349_1229_828.png → NEV
# Copiada: PAT_1374_1284_208.png → ACK
# Copiada: PAT_609_1159_932.png → BCC
# Copiada: PAT_1090_376_384.png → ACK
# Copiada: PAT_370_2558_175.png → ACK
# Copiada: PAT_225_345_903.png → ACK
# Copiada: PAT_1371_1276_145.png → ACK
# Copiada: PAT_71_108_617.png → ACK
# Copiada: PAT_475_913_874.png → BCC
# Copiada: PAT_1273_952_89.png → NEV
# Copiada: PAT_1712_3173_684.png → ACK
# Copiada: PAT_212_327_532.png → BCC
# Copiada: PAT_1340_1208_931.png → SEK
# Copiada: PAT_1420_1460_951.png → SEK
# Copiada: PAT_935_1786_482.png → SCC
# Copiada: PAT_258_397_198.png → BCC
# Copiada: PAT_168_260_654.png → BCC
# Copiada: PAT_439_2887_834.png → NEV
# Copiada: PAT_596_1146_294.png → BCC
# Copiada: PAT_314_672_909.png → BCC
# Copiada: PAT_255_388_231.png → BCC
# Copiada: PAT_809_1527_202.png → SCC
# Copiada: PAT_224_343_782.png → BCC
# Copiada: PAT_959_1813_1000.png → BCC
# Copiada: PAT_1551_1889_948.png → ACK
# Copiada: PAT_1944_3921_281.png → SEK
# Copiada: PAT_1741_3273_34.png → ACK
# Copiada: PAT_1065_276_231.png → ACK
# Copiada: PAT_2034_4269_670.png → ACK
# Copiada: PAT_448_875_81.png → SCC
# Copiada: PAT_773_1459_554.png → BCC
# Copiada: PAT_1415_1437_527.png → SEK
# Copiada: PAT_1735_3241_207.png → NEV
# Copiada: PAT_2053_4360_281.png → SEK
# Copiada: PAT_90_139_57.png → BCC
# Copiada: PAT_827_1598_85.png → BCC
# Copiada: PAT_1780_3380_542.png → SEK
# Copiada: PAT_1529_1798_206.png → SEK
# Copiada: PAT_954_1808_415.png → BCC
# Copiada: PAT_471_909_394.png → NEV
# Copiada: PAT_1288_1003_553.png → NEV
# Copiada: PAT_337_706_598.png → BCC
# Copiada: PAT_817_4471_179.png → ACK
# Copiada: PAT_1892_3760_713.png → ACK
# Copiada: PAT_1326_1156_163.png → NEV
# Copiada: PAT_771_1488_922.png → SCC
# Copiada: PAT_379_1531_17.png → BCC
# Copiada: PAT_2065_4412_407.png → SEK
# Copiada: PAT_921_1750_313.png → ACK
# Copiada: PAT_392_792_712.png → BCC
# Copiada: PAT_768_1449_842.png → SCC
# Copiada: PAT_1764_3336_981.png → SEK
# Copiada: PAT_633_1199_218.png → SCC
# Copiada: PAT_53_1144_892.png → BCC
# Copiada: PAT_528_3072_615.png → ACK
# Copiada: PAT_2119_4625_733.png → ACK
# Copiada: PAT_473_911_610.png → BCC
# Copiada: PAT_816_1544_933.png → BCC
# Copiada: PAT_330_698_302.png → BCC
# Copiada: PAT_159_246_630.png → BCC
# Copiada: PAT_571_1096_10.png → BCC
# Copiada: PAT_1481_1675_371.png → ACK
# Copiada: PAT_510_959_985.png → BCC
# Copiada: PAT_409_2614_805.png → ACK
# Copiada: PAT_768_1450_402.png → BCC
# Copiada: PAT_1216_759_542.png → NEV
# Copiada: PAT_123_186_718.png → BCC
# Copiada: PAT_1626_2811_850.png → SEK
# Copiada: PAT_1133_510_956.png → ACK
# Copiada: PAT_59_93_342.png → BCC
# Copiada: PAT_330_1440_532.png → SCC
# Copiada: PAT_1934_3890_306.png → NEV
# Copiada: PAT_1203_724_762.png → SEK
# Copiada: PAT_2098_4559_436.png → ACK
# Copiada: PAT_1275_955_131.png → ACK
# Copiada: PAT_798_1529_282.png → NEV
# Copiada: PAT_796_1509_400.png → BCC
# Copiada: PAT_373_2598_514.png → SEK
# Copiada: PAT_1221_766_430.png → SEK
# Copiada: PAT_167_684_365.png → ACK
# Copiada: PAT_535_1010_303.png → BCC
# Copiada: PAT_798_1771_240.png → ACK
# Copiada: PAT_150_1799_644.png → SCC
# Copiada: PAT_192_296_824.png → SCC
# Copiada: PAT_142_210_904.png → BCC
# Copiada: PAT_1555_2396_71.png → SEK
# Copiada: PAT_528_993_589.png → ACK
# Copiada: PAT_722_1376_280.png → BCC
# Copiada: PAT_953_1806_845.png → SCC
# Copiada: PAT_340_714_314.png → MEL
# Copiada: PAT_1170_609_378.png → ACK
# Copiada: PAT_845_1604_313.png → BCC
# Copiada: PAT_996_6_367.png → ACK
# Copiada: PAT_2122_4642_204.png → ACK
# Copiada: PAT_168_262_292.png → BCC
# Copiada: PAT_277_427_658.png → ACK
# Copiada: PAT_38_1003_226.png → ACK
# Copiada: PAT_903_1720_647.png → BCC
# Copiada: PAT_2039_4290_273.png → ACK
# Copiada: PAT_1727_3233_399.png → ACK
# Copiada: PAT_272_419_906.png → BCC
# Copiada: PAT_29_40_561.png → NEV
# Copiada: PAT_164_255_119.png → SCC
# Copiada: PAT_238_364_387.png → ACK
# Copiada: PAT_1955_3946_319.png → ACK
# Copiada: PAT_944_1795_666.png → BCC
# Copiada: PAT_490_933_17.png → SCC
# Copiada: PAT_180_279_746.png → BCC
# Copiada: PAT_789_1483_793.png → BCC
# Copiada: PAT_1767_3340_959.png → ACK
# Copiada: PAT_1408_1404_929.png → SEK
# Copiada: PAT_1951_3934_98.png → ACK
# Copiada: PAT_177_775_786.png → ACK
# Copiada: PAT_1483_1678_538.png → ACK
# Copiada: PAT_711_4067_260.png → ACK
# Copiada: PAT_914_1740_932.png → ACK
# Copiada: PAT_53_81_522.png → BCC
# Copiada: PAT_1370_1273_41.png → ACK
# Copiada: PAT_457_890_255.png → ACK
# Copiada: PAT_494_939_518.png → BCC
# Copiada: PAT_835_1578_52.png → BCC
# Copiada: PAT_325_689_528.png → SCC
# Copiada: PAT_344_718_206.png → NEV
# Copiada: PAT_1088_373_781.png → ACK
# Copiada: PAT_1061_254_813.png → ACK
# Copiada: PAT_432_851_386.png → BCC
# Copiada: PAT_27_38_240.png → ACK
# Copiada: PAT_2036_4280_90.png → ACK
# Copiada: PAT_147_219_544.png → BCC
# Copiada: PAT_2150_4766_754.png → ACK
# Copiada: PAT_267_1062_418.png → BCC
# Copiada: PAT_2090_4532_178.png → ACK
# Copiada: PAT_2049_4348_485.png → SEK
# Copiada: PAT_753_1833_710.png → ACK
# Copiada: PAT_968_1835_721.png → BCC
# Copiada: PAT_717_1347_899.png → MEL
# Copiada: PAT_1605_2715_845.png → ACK
# Copiada: PAT_1650_2913_374.png → ACK
# Copiada: PAT_354_1814_153.png → SEK
# Copiada: PAT_1208_736_599.png → NEV
# Copiada: PAT_852_1629_265.png → BCC
# Copiada: PAT_2105_4587_204.png → ACK
# Copiada: PAT_1066_281_698.png → ACK
# Copiada: PAT_1308_1095_117.png → NEV
# Copiada: PAT_379_4405_969.png → ACK
# Copiada: PAT_677_1350_67.png → ACK
# Copiada: PAT_217_1290_283.png → BCC
# Copiada: PAT_742_1402_818.png → ACK
# Copiada: PAT_1288_1003_969.png → NEV
# Copiada: PAT_1780_3381_999.png → NEV
# Copiada: PAT_846_4421_153.png → ACK
# Copiada: PAT_605_1152_536.png → SCC
# Copiada: PAT_613_1164_827.png → BCC
# Copiada: PAT_1819_3569_217.png → ACK
# Copiada: PAT_881_1681_462.png → SCC
# Copiada: PAT_1636_2869_595.png → SEK
# Copiada: PAT_75_113_165.png → SCC
# Copiada: PAT_817_1537_943.png → BCC
# Copiada: PAT_1772_3346_66.png → NEV
# Copiada: PAT_786_1480_914.png → BCC
# Copiada: PAT_269_415_103.png → BCC
# Copiada: PAT_788_1503_541.png → BCC
# Copiada: PAT_823_1558_67.png → BCC
# Copiada: PAT_1988_4052_897.png → SEK
# Copiada: PAT_492_937_126.png → SCC
# Copiada: PAT_386_1554_455.png → BCC
# Copiada: PAT_1307_1088_252.png → SEK
# Copiada: PAT_1557_2399_681.png → ACK
# Copiada: PAT_40_56_160.png → BCC
# Copiada: PAT_1837_3608_851.png → NEV
# Copiada: PAT_313_669_908.png → BCC
# Copiada: PAT_464_900_548.png → BCC
# Copiada: PAT_658_1266_149.png → BCC
# Copiada: PAT_1801_3459_857.png → NEV
# Copiada: PAT_657_1247_455.png → BCC
# Copiada: PAT_154_235_30.png → BCC
# Copiada: PAT_1505_1733_128.png → ACK
# Copiada: PAT_1377_3512_370.png → SEK
# Copiada: PAT_810_1526_67.png → BCC
# Copiada: PAT_1186_680_578.png → NEV
# Copiada: PAT_270_1387_430.png → SEK
# Copiada: PAT_419_2767_323.png → ACK
# Copiada: PAT_2030_4246_973.png → NEV
# Copiada: PAT_2092_4537_438.png → SEK
# Copiada: PAT_343_717_927.png → SEK
# Copiada: PAT_1364_1246_143.png → NEV
# Copiada: PAT_2016_4156_941.png → SEK
# Copiada: PAT_1573_2497_736.png → ACK
# Copiada: PAT_935_1785_530.png → SCC
# Copiada: PAT_1034_161_203.png → ACK
# Copiada: PAT_637_1434_684.png → SCC
# Copiada: PAT_610_1156_461.png → BCC
# Copiada: PAT_252_383_31.png → BCC
# Copiada: PAT_890_1694_29.png → NEV
# Copiada: PAT_96_150_743.png → BCC
# Copiada: PAT_1708_3155_581.png → ACK
# Copiada: PAT_756_1496_480.png → NEV
# Copiada: PAT_745_1406_409.png → BCC
# Copiada: PAT_1723_3218_111.png → SEK
# Copiada: PAT_1350_1230_925.png → NEV
# Copiada: PAT_309_663_812.png → ACK
# Copiada: PAT_104_1754_276.png → ACK
# Copiada: PAT_797_1511_805.png → BCC
# Copiada: PAT_928_1764_426.png → BCC
# Copiada: PAT_397_797_638.png → SCC
# Copiada: PAT_818_1539_859.png → BCC
# Copiada: PAT_1405_1395_96.png → ACK
# Copiada: PAT_260_1289_396.png → ACK
# Copiada: PAT_506_957_377.png → BCC
# Copiada: PAT_579_1099_837.png → ACK
# Copiada: PAT_1570_2472_418.png → NEV
# Copiada: PAT_918_1742_456.png → BCC
# Copiada: PAT_1246_846_899.png → ACK
# Copiada: PAT_579_1100_988.png → ACK
# Copiada: PAT_1367_1264_801.png → ACK
# Copiada: PAT_993_1865_559.png → BCC
# Copiada: PAT_268_413_643.png → BCC
# Copiada: PAT_207_313_1.png → BCC
# Copiada: PAT_1374_1285_735.png → ACK
# Copiada: PAT_1406_1396_511.png → SEK
# Copiada: PAT_173_268_1000.png → NEV
# Copiada: PAT_342_716_316.png → BCC
# Copiada: PAT_970_1833_270.png → BCC
# Copiada: PAT_996_6_622.png → ACK
# Copiada: PAT_651_1232_950.png → ACK
# Copiada: PAT_1600_2685_164.png → ACK
# Copiada: PAT_1807_3481_801.png → ACK
# Copiada: PAT_960_1816_662.png → ACK
# Copiada: PAT_245_376_24.png → BCC
# Copiada: PAT_1755_3310_986.png → NEV
# Copiada: PAT_1006_53_385.png → ACK
# Copiada: PAT_1569_2456_393.png → SEK
# Copiada: PAT_380_773_362.png → BCC
# Copiada: PAT_834_1574_276.png → SCC
# Copiada: PAT_163_254_719.png → ACK
# Copiada: PAT_265_407_421.png → BCC
# Copiada: PAT_674_1277_9.png → BCC
# Copiada: PAT_1800_3460_206.png → SEK
# Copiada: PAT_534_1009_924.png → BCC
# Copiada: PAT_585_1130_552.png → ACK
# Copiada: PAT_690_1309_154.png → BCC
# Copiada: PAT_1577_2543_510.png → SEK
# Copiada: PAT_2024_4224_141.png → ACK
# Copiada: PAT_2034_4266_880.png → ACK
# Copiada: PAT_505_951_710.png → BCC
# Copiada: PAT_1475_1651_727.png → ACK
# Copiada: PAT_1761_3329_837.png → SEK
# Copiada: PAT_564_1079_430.png → BCC
# Copiada: PAT_747_1409_116.png → ACK
# Copiada: PAT_566_179_23.png → ACK
# Copiada: PAT_719_1361_234.png → MEL
# Copiada: PAT_1893_3761_666.png → ACK
# Copiada: PAT_1486_1684_182.png → ACK
# Copiada: PAT_2129_4680_110.png → NEV
# Copiada: PAT_1739_3261_325.png → ACK
# Copiada: PAT_1034_160_819.png → ACK
# Copiada: PAT_950_1804_334.png → BCC
# Copiada: PAT_1536_1819_91.png → ACK
# Copiada: PAT_1402_1376_507.png → ACK
# Copiada: PAT_406_808_975.png → BCC
# Copiada: PAT_237_362_52.png → BCC
# Copiada: PAT_900_1711_622.png → NEV
# Copiada: PAT_504_953_569.png → SEK
# Copiada: PAT_2153_4782_321.png → ACK
# Copiada: PAT_1729_3235_712.png → ACK
# Copiada: PAT_593_1127_823.png → BCC
# Copiada: PAT_1670_3007_105.png → ACK
# Copiada: PAT_673_1276_752.png → ACK
# Copiada: PAT_487_930_973.png → SCC
# Copiada: PAT_15_3138_959.png → ACK
# Copiada: PAT_1180_651_559.png → NEV
# Copiada: PAT_1261_896_349.png → SEK
# Copiada: PAT_931_1762_69.png → ACK
# Copiada: PAT_678_1298_396.png → SCC
# Copiada: PAT_810_1526_639.png → BCC
# Copiada: PAT_83_126_820.png → BCC
# Copiada: PAT_1220_765_464.png → SEK
# Copiada: PAT_987_1859_859.png → ACK
# Copiada: PAT_638_3680_891.png → ACK
# Copiada: PAT_901_1716_497.png → BCC
# Copiada: PAT_735_1391_261.png → ACK
# Copiada: PAT_787_1482_328.png → SCC
# Copiada: PAT_467_904_535.png → BCC
# Copiada: PAT_684_1303_178.png → BCC
# Copiada: PAT_822_1550_132.png → BCC
# Copiada: PAT_1296_1038_1.png → ACK
# Copiada: PAT_629_1192_362.png → SCC
# Copiada: PAT_1286_1000_276.png → SEK
# Copiada: PAT_1603_2704_969.png → NEV
# Copiada: PAT_919_1744_451.png → BCC
# Copiada: PAT_1305_1082_88.png → NEV
# Copiada: PAT_1452_1564_377.png → ACK
# Copiada: PAT_650_1241_329.png → BCC
# Copiada: PAT_625_1184_412.png → SEK
# Copiada: PAT_460_894_242.png → BCC
# Copiada: PAT_1534_1809_366.png → NEV
# Copiada: PAT_2099_4562_100.png → NEV
# Copiada: PAT_352_729_947.png → NEV
# Copiada: PAT_126_190_376.png → ACK
# Copiada: PAT_626_1187_34.png → BCC
# Copiada: PAT_633_1199_745.png → SCC
# Copiada: PAT_902_1718_852.png → MEL
# Copiada: PAT_1412_1421_512.png → ACK
# Copiada: PAT_877_1667_118.png → BCC
# Copiada: PAT_210_316_401.png → ACK
# Copiada: PAT_645_1222_860.png → BCC
# Copiada: PAT_478_916_979.png → BCC
# Copiada: PAT_377_1580_429.png → SCC
# Copiada: PAT_873_1661_178.png → ACK
# Copiada: PAT_565_1073_749.png → BCC
# Copiada: PAT_386_784_470.png → SCC
# Copiada: PAT_1393_1355_316.png → ACK
# Copiada: PAT_108_161_878.png → SCC
# Copiada: PAT_1940_3902_876.png → NEV
# Copiada: PAT_545_1029_650.png → BCC
# Copiada: PAT_1746_3284_798.png → ACK
# Copiada: PAT_704_1324_359.png → ACK
# Copiada: PAT_2020_4176_865.png → ACK
# Copiada: PAT_1138_520_154.png → NEV
# Copiada: PAT_380_774_185.png → ACK
# Copiada: PAT_559_1093_774.png → BCC
# Copiada: PAT_2093_4542_192.png → ACK
# Copiada: PAT_1468_1622_219.png → ACK
# Copiada: PAT_387_786_213.png → SCC
# Copiada: PAT_1975_3999_453.png → SEK
# Copiada: PAT_1728_3234_404.png → ACK
# Copiada: PAT_1563_2426_436.png → ACK
# Copiada: PAT_366_2448_563.png → ACK
# Copiada: PAT_711_1334_480.png → BCC
# Copiada: PAT_428_845_189.png → ACK
# Copiada: PAT_1186_681_457.png → NEV
# Copiada: PAT_802_1516_510.png → ACK
# Copiada: PAT_2003_4107_766.png → ACK
# Copiada: PAT_2116_4614_671.png → ACK
# Copiada: PAT_211_318_942.png → BCC
# Copiada: PAT_316_674_318.png → BCC
# Copiada: PAT_1351_1231_203.png → NEV
# Copiada: PAT_806_1520_60.png → BCC
# Copiada: PAT_88_133_64.png → BCC
# Copiada: PAT_1177_633_705.png → ACK
# Copiada: PAT_1113_458_387.png → NEV
# Copiada: PAT_1698_3122_83.png → NEV
# Copiada: PAT_2085_4506_726.png → SEK
# Copiada: PAT_1243_837_806.png → ACK
# Copiada: PAT_688_1305_242.png → BCC
# Copiada: PAT_67_104_695.png → BCC
# Copiada: PAT_2108_4596_837.png → SEK
# Copiada: PAT_471_909_353.png → NEV
# Copiada: PAT_621_3592_955.png → NEV
# Copiada: PAT_1118_470_710.png → ACK
# Copiada: PAT_1286_999_846.png → SEK
# Copiada: PAT_1046_203_511.png → SEK
# Copiada: PAT_202_917_942.png → ACK
# Copiada: PAT_456_888_961.png → BCC
# Copiada: PAT_316_1457_353.png → ACK
# Copiada: PAT_177_274_865.png → BCC
# Copiada: PAT_93_361_53.png → SEK
# Copiada: PAT_330_1437_458.png → BCC
# Copiada: PAT_615_1167_722.png → NEV
# Copiada: PAT_1340_1207_304.png → SEK
# Copiada: PAT_988_1858_453.png → BCC
# Copiada: PAT_2024_4225_170.png → ACK
# Copiada: PAT_947_1798_946.png → BCC
# Copiada: PAT_782_1492_890.png → BCC
# Copiada: PAT_299_1452_1.png → BCC
# Copiada: PAT_874_1672_287.png → SCC
# Copiada: PAT_893_1697_613.png → SEK
# Copiada: PAT_351_728_683.png → BCC
# Copiada: PAT_402_803_739.png → BCC
# Copiada: PAT_1179_641_735.png → NEV
# Copiada: PAT_282_433_934.png → BCC
# Copiada: PAT_156_241_538.png → BCC
# Copiada: PAT_1153_555_98.png → NEV
# Copiada: PAT_660_1249_469.png → BCC
# Copiada: PAT_762_1436_414.png → BCC
# Copiada: PAT_1373_1283_85.png → ACK
# Copiada: PAT_1689_3077_411.png → NEV
# Copiada: PAT_669_1265_76.png → BCC
# Copiada: PAT_1414_1433_806.png → ACK
# Copiada: PAT_861_1639_823.png → ACK
# Copiada: PAT_1031_148_292.png → ACK
# Copiada: PAT_261_401_911.png → BCC
# Copiada: PAT_110_165_583.png → BCC
# Copiada: PAT_281_1517_293.png → NEV
# Copiada: PAT_880_1675_704.png → ACK
# Copiada: PAT_2017_4164_500.png → NEV
# Copiada: PAT_197_301_449.png → BCC
# Copiada: PAT_486_929_274.png → MEL
# Copiada: PAT_955_1810_892.png → BCC
# Copiada: PAT_1093_379_273.png → ACK
# Copiada: PAT_481_923_186.png → BCC
# Copiada: PAT_938_1790_977.png → BCC
# Copiada: PAT_645_1223_443.png → BCC
# Copiada: PAT_86_1082_220.png → ACK
# Copiada: PAT_477_915_389.png → BCC
# Copiada: PAT_1946_3924_24.png → SEK
# Copiada: PAT_885_1687_204.png → BCC
# Copiada: PAT_1931_3879_727.png → ACK
# Copiada: PAT_904_1736_851.png → BCC
# Copiada: PAT_32_44_211.png → BCC
# Copiada: PAT_815_1536_963.png → BCC
# Copiada: PAT_303_652_342.png → BCC
# Copiada: PAT_330_695_296.png → BCC
# Copiada: PAT_363_746_18.png → BCC
# Copiada: PAT_645_4042_489.png → ACK
# Copiada: PAT_388_1590_328.png → BCC
# Copiada: PAT_747_1410_622.png → ACK
# Copiada: PAT_983_1853_985.png → ACK
# Copiada: PAT_110_397_52.png → ACK
# Copiada: PAT_191_294_419.png → BCC
# Copiada: PAT_1450_1556_114.png → ACK
# Copiada: PAT_451_878_890.png → BCC
# Copiada: PAT_691_3994_791.png → ACK
# Copiada: PAT_1918_3836_82.png → ACK
# Copiada: PAT_430_848_550.png → BCC
# Copiada: PAT_1184_676_303.png → ACK
# Copiada: PAT_2161_4818_501.png → NEV
# Copiada: PAT_876_1666_961.png → BCC
# Copiada: PAT_1790_3427_723.png → ACK
# Copiada: PAT_1453_1566_310.png → SEK
# Copiada: PAT_1176_631_36.png → ACK
# Copiada: PAT_523_988_900.png → BCC
# Copiada: PAT_1545_1865_519.png → ACK
# Copiada: PAT_637_1217_274.png → SCC
# Copiada: PAT_887_1688_436.png → BCC
# Copiada: PAT_1469_1627_109.png → ACK
# Copiada: PAT_447_873_329.png → SCC
# Copiada: PAT_1840_3612_959.png → ACK
# Copiada: PAT_1587_2625_226.png → NEV
# Copiada: PAT_897_1710_793.png → BCC
# Copiada: PAT_931_1761_380.png → ACK
# Copiada: PAT_1937_3897_131.png → ACK
# Copiada: PAT_936_1772_886.png → MEL
# Copiada: PAT_691_1311_890.png → BCC
# Copiada: PAT_359_1596_68.png → ACK
# ...
# Copiada: PAT_568_1066_235.png → BCC
# Copiada: PAT_451_878_634.png → BCC
# Copiada: PAT_166_257_586.png → BCC
# Copiada: PAT_815_1533_460.png → BCC
# Copiada: PAT_257_396_494.png → BCC
# Copiada: PAT_963_1817_593.png → SCC
# Copiada: PAT_660_1249_373.png → BCC
# Copiada: PAT_1320_1135_471.png → ACK
# Copiada: PAT_860_1641_998.png → SCC
# Copiada: PAT_857_1627_310.png → SCC
# Copiada: PAT_1636_2869_739.png → SEK
# Copiada: PAT_829_1566_135.png → BCC
# Copiada: PAT_50_76_728.png → BCC
# Copiada: PAT_1786_3420_346.png → ACK
# Copiada: PAT_1414_1429_53.png → ACK
# Copiada: PAT_51_78_959.png → SCC
# Copiada: PAT_937_1768_126.png → ACK
# Copiada: PAT_626_1186_898.png → BCC
# Copiada: PAT_263_403_382.png → SCC
# Copiada: PAT_1498_1715_345.png → ACK
# Copiada: PAT_1534_1810_719.png → NEV
# Copiada: PAT_368_1652_733.png → BCC
# Copiada: PAT_1364_1246_238.png → NEV
# Copiada: PAT_441_2868_663.png → ACK
# Copiada: PAT_360_742_782.png → SCC
# Copiada: PAT_650_1230_636.png → BCC
# Copiada: PAT_756_1496_599.png → NEV
# Copiada: PAT_514_969_995.png → BCC
# Copiada: PAT_1653_2916_994.png → SEK
# Copiada: PAT_1326_1156_783.png → NEV
# Copiada: PAT_686_1355_168.png → SCC
# Copiada: PAT_1811_3487_560.png → ACK
# Copiada: PAT_1282_978_328.png → ACK
# Copiada: PAT_874_1672_743.png → SCC
# Copiada: PAT_883_1682_256.png → ACK
# Copiada: PAT_71_145_971.png → ACK
# Copiada: PAT_599_1140_399.png → ACK
# Copiada: PAT_628_1191_564.png → BCC
# Copiada: PAT_1245_844_471.png → NEV
# Copiada: PAT_375_764_705.png → BCC
# Copiada: PAT_1161_578_233.png → NEV
# Copiada: PAT_1740_3272_228.png → ACK
# Copiada: PAT_2159_4792_718.png → NEV
# Copiada: PAT_830_1565_911.png → BCC
# Copiada: PAT_269_415_906.png → BCC
# Copiada: PAT_369_755_733.png → SCC
# Copiada: PAT_187_287_482.png → BCC
# Copiada: PAT_567_1078_978.png → BCC
# Copiada: PAT_1428_1489_454.png → ACK
# Copiada: PAT_912_1729_244.png → BCC
# Copiada: PAT_63_1075_331.png → BCC
# Copiada: PAT_1854_3637_323.png → ACK
# Copiada: PAT_188_289_859.png → BCC
# Copiada: PAT_480_921_1.png → BCC
# Copiada: PAT_1730_3236_201.png → SEK
# Copiada: PAT_299_1455_759.png → BCC
# Copiada: PAT_1718_3202_152.png → NEV
# Copiada: PAT_1694_3110_213.png → NEV
# Copiada: PAT_453_883_719.png → BCC
# Copiada: PAT_1804_3469_628.png → ACK
# Copiada: PAT_59_93_573.png → BCC
# Copiada: PAT_1581_2570_738.png → ACK
# Copiada: PAT_1136_517_92.png → NEV
# Copiada: PAT_662_1251_43.png → BCC
# Copiada: PAT_1278_966_295.png → ACK
# Copiada: PAT_656_1246_489.png → MEL
# Copiada: PAT_1324_1146_143.png → ACK
# Copiada: PAT_230_1009_92.png → ACK
# Copiada: PAT_56_88_274.png → BCC
# Copiada: PAT_1333_1177_434.png → NEV
# Copiada: PAT_193_297_295.png → BCC
# Copiada: PAT_771_1489_70.png → SCC
# Copiada: PAT_260_400_566.png → ACK
# Copiada: PAT_419_833_148.png → SCC
# Copiada: PAT_757_1431_907.png → ACK
# Copiada: PAT_1547_4231_928.png → ACK
# Copiada: PAT_445_871_524.png → BCC
# Copiada: PAT_904_1737_511.png → BCC
# Copiada: PAT_325_1506_440.png → ACK
# Copiada: PAT_866_1649_674.png → BCC
# Copiada: PAT_370_2558_573.png → ACK
# Copiada: PAT_471_909_344.png → NEV
# Copiada: PAT_864_1645_626.png → BCC
# Copiada: PAT_1575_2516_618.png → ACK
# Copiada: PAT_300_1689_862.png → ACK
# Copiada: PAT_753_1834_712.png → ACK
# Copiada: PAT_263_1480_753.png → ACK
# Copiada: PAT_1312_1102_578.png → SEK
# Copiada: PAT_1033_153_301.png → ACK
# Copiada: PAT_972_1843_756.png → MEL
# Copiada: PAT_1245_845_32.png → NEV
# Copiada: PAT_716_1345_460.png → BCC
# Copiada: PAT_2088_4525_507.png → NEV
# Copiada: PAT_161_250_197.png → BCC
# Copiada: PAT_665_1261_17.png → NEV
# Copiada: PAT_417_828_723.png → NEV
# Copiada: PAT_1332_1174_839.png → SEK
# Copiada: PAT_823_1556_787.png → BCC
# Copiada: PAT_14_22_850.png → BCC
# Copiada: PAT_272_420_10.png → BCC
# Copiada: PAT_1274_954_677.png → ACK
# Copiada: PAT_1223_770_120.png → NEV
# Copiada: PAT_1726_3228_674.png → ACK
# Copiada: PAT_73_111_609.png → BCC
# Copiada: PAT_677_1348_657.png → BCC
# Copiada: PAT_100_393_898.png → NEV
# Copiada: PAT_1492_1705_728.png → ACK
# Copiada: PAT_720_1362_700.png → BCC
# Copiada: PAT_439_859_84.png → NEV
# Copiada: PAT_1547_1876_839.png → ACK
# Copiada: PAT_2079_4480_586.png → ACK
# Copiada: PAT_876_1665_569.png → BCC
# Copiada: PAT_237_363_858.png → BCC
# Copiada: PAT_388_1592_576.png → BCC
# Copiada: PAT_58_91_845.png → BCC
# Copiada: PAT_36_50_14.png → ACK
# Copiada: PAT_201_306_781.png → NEV
# Copiada: PAT_771_1490_334.png → BCC
# Copiada: PAT_84_128_233.png → BCC
# Copiada: PAT_1301_1063_739.png → ACK
# Copiada: PAT_1401_1374_593.png → NEV
# Copiada: PAT_1184_678_86.png → SEK
# Copiada: PAT_478_1829_141.png → BCC
# Copiada: PAT_181_280_417.png → SCC
# Copiada: PAT_364_748_278.png → BCC
# Copiada: PAT_251_382_576.png → BCC
# Copiada: PAT_1249_861_810.png → ACK
# Copiada: PAT_191_293_314.png → BCC
# Copiada: PAT_573_1090_164.png → BCC
# Copiada: PAT_1928_3876_437.png → NEV
# Copiada: PAT_1407_1402_347.png → ACK
# Copiada: PAT_834_1572_430.png → SCC
# Copiada: PAT_1310_1097_774.png → SEK
# Copiada: PAT_318_677_278.png → BCC
# Copiada: PAT_46_879_386.png → BCC
# Copiada: PAT_1411_1415_723.png → SEK
# Copiada: PAT_641_3704_317.png → NEV
# Copiada: PAT_242_369_930.png → BCC
# Copiada: PAT_13_21_350.png → BCC
# Copiada: PAT_1495_1708_278.png → SEK
# Copiada: PAT_248_379_695.png → BCC
# Copiada: PAT_1345_1223_175.png → NEV
# Copiada: PAT_392_792_22.png → BCC
# Copiada: PAT_146_217_187.png → BCC
# Copiada: PAT_1216_760_593.png → ACK
# Copiada: PAT_367_753_130.png → SCC
# Copiada: PAT_570_1084_637.png → SCC
# Copiada: PAT_570_1085_344.png → BCC
# Copiada: PAT_986_1855_702.png → BCC
# Copiada: PAT_1671_3008_622.png → NEV
# Copiada: PAT_370_758_322.png → ACK
# Copiada: PAT_1063_268_919.png → ACK
# Copiada: PAT_1464_1612_284.png → ACK
# Copiada: PAT_422_837_617.png → BCC
# Copiada: PAT_662_1251_380.png → BCC
# Copiada: PAT_575_1087_29.png → BCC
# Copiada: PAT_383_777_129.png → SCC
# Copiada: PAT_1089_375_60.png → NEV
# Copiada: PAT_388_1589_976.png → ACK
# Copiada: PAT_93_361_51.png → SEK
# Copiada: PAT_545_1031_428.png → BCC
# Copiada: PAT_406_1542_754.png → BCC
# Copiada: PAT_872_1709_526.png → ACK
# Copiada: PAT_1241_824_82.png → SEK
# Copiada: PAT_949_1802_582.png → MEL
# Copiada: PAT_169_694_411.png → ACK
# Copiada: PAT_537_1014_452.png → SCC
# Copiada: PAT_277_1309_814.png → ACK
# Copiada: PAT_632_1206_634.png → SCC
# Copiada: PAT_1184_676_904.png → ACK
# Copiada: PAT_1946_3924_929.png → SEK
# Copiada: PAT_632_1206_637.png → SCC
# Copiada: PAT_822_1551_573.png → BCC
# Copiada: PAT_683_1297_195.png → BCC
# Copiada: PAT_982_1852_526.png → ACK
# Copiada: PAT_574_1081_628.png → SCC
# Copiada: PAT_1408_1406_950.png → SEK
# Copiada: PAT_736_1392_562.png → BCC
# Copiada: PAT_691_1312_389.png → MEL
# Copiada: PAT_687_1304_898.png → BCC
# Copiada: PAT_838_1585_979.png → BCC
# Copiada: PAT_1414_1426_124.png → SEK
# Copiada: PAT_719_1361_160.png → MEL
# Copiada: PAT_1107_427_352.png → NEV
# Copiada: PAT_992_1864_653.png → ACK
# Copiada: PAT_1051_220_356.png → ACK
# Copiada: PAT_1209_737_590.png → ACK
# Copiada: PAT_2152_4781_332.png → SEK
# Copiada: PAT_323_687_169.png → SCC
# Copiada: PAT_833_1571_134.png → BCC
# Copiada: PAT_233_354_828.png → MEL
# Copiada: PAT_1536_1819_562.png → ACK
# Copiada: PAT_387_1614_866.png → BCC
# Copiada: PAT_1707_3148_237.png → ACK
# Copiada: PAT_851_4520_743.png → SEK
# Copiada: PAT_167_258_479.png → BCC
# Copiada: PAT_1755_3309_828.png → SEK
# Copiada: PAT_710_1330_243.png → MEL
# Copiada: PAT_145_216_110.png → BCC
# Copiada: PAT_317_675_144.png → ACK
# Copiada: PAT_942_1792_411.png → ACK
# Copiada: PAT_324_1465_43.png → SCC
# Copiada: PAT_894_1679_640.png → MEL
# Copiada: PAT_373_2598_235.png → SEK
# Copiada: PAT_31_43_129.png → BCC
# Copiada: PAT_220_338_339.png → SCC
# Copiada: PAT_1980_4018_929.png → ACK
# Copiada: PAT_69_1053_332.png → ACK
# Copiada: PAT_454_884_28.png → SCC
# Copiada: PAT_1855_3641_327.png → ACK
# Copiada: PAT_1074_322_864.png → ACK
# Copiada: PAT_213_328_117.png → NEV
# Copiada: PAT_980_1849_295.png → BCC
# Copiada: PAT_91_140_664.png → ACK
# Copiada: PAT_369_756_130.png → SCC
# Copiada: PAT_1303_1077_501.png → ACK
# Copiada: PAT_484_926_624.png → ACK
# Copiada: PAT_742_1470_834.png → ACK
# Copiada: PAT_215_330_341.png → SCC
# Copiada: PAT_1185_679_115.png → SEK
# Copiada: PAT_404_805_575.png → ACK
# Copiada: PAT_890_1693_904.png → MEL
# Copiada: PAT_756_1495_858.png → NEV
# Copiada: PAT_1554_2392_767.png → SEK
# Copiada: PAT_1969_3980_995.png → ACK
# Copiada: PAT_1202_722_827.png → SEK
# Copiada: PAT_101_1041_898.png → BCC
# Copiada: PAT_388_4500_103.png → ACK
# Copiada: PAT_455_885_115.png → BCC
# Copiada: PAT_2013_4148_303.png → NEV
# Copiada: PAT_307_1685_651.png → ACK
# Copiada: PAT_844_1605_308.png → SCC
# Copiada: PAT_172_267_557.png → BCC
# Copiada: PAT_93_361_467.png → SEK
# Copiada: PAT_1415_1440_629.png → ACK
# Copiada: PAT_1414_1433_570.png → ACK
# Copiada: PAT_355_732_102.png → BCC
# Copiada: PAT_2062_4397_39.png → NEV
# Copiada: PAT_561_1068_557.png → BCC
# Copiada: PAT_781_1474_517.png → BCC
# Copiada: PAT_2123_4647_95.png → ACK
# Copiada: PAT_1571_2484_488.png → ACK
# Copiada: PAT_1520_1777_935.png → NEV
# Copiada: PAT_247_1294_292.png → BCC
# Copiada: PAT_406_808_560.png → BCC
# Copiada: PAT_78_118_164.png → BCC
# Copiada: PAT_81_123_52.png → ACK
# Copiada: PAT_2077_4463_77.png → ACK
# Copiada: PAT_935_1781_920.png → BCC
# Copiada: PAT_798_1770_256.png → ACK
# Copiada: PAT_377_768_643.png → BCC
# Copiada: PAT_920_1748_942.png → ACK
# Copiada: PAT_118_180_500.png → BCC
# Copiada: PAT_684_1303_368.png → BCC
# Copiada: PAT_890_1693_454.png → MEL
# Copiada: PAT_1787_3421_516.png → NEV
# Copiada: PAT_1421_1464_297.png → ACK
# Copiada: PAT_70_107_155.png → MEL
# Copiada: PAT_464_1794_271.png → BCC
# Copiada: PAT_636_1204_666.png → BCC
# Copiada: PAT_943_1793_256.png → BCC
# Copiada: PAT_522_3168_747.png → NEV
# Copiada: PAT_562_1110_360.png → BCC
# Copiada: PAT_689_1307_354.png → SCC
# Copiada: PAT_223_1068_246.png → ACK
# Copiada: PAT_1260_894_63.png → ACK
# Copiada: PAT_1148_542_708.png → NEV
# Copiada: PAT_878_1663_7.png → ACK
# Copiada: PAT_983_1854_274.png → ACK
# Copiada: PAT_75_113_647.png → SCC
# Copiada: PAT_159_245_181.png → BCC
# Copiada: PAT_2161_4819_719.png → NEV
# Copiada: PAT_1850_3631_519.png → ACK
# Copiada: PAT_2024_4221_632.png → ACK
# Copiada: PAT_78_118_685.png → BCC
# Copiada: PAT_217_332_906.png → BCC
# Copiada: PAT_1633_2855_460.png → ACK
# Copiada: PAT_202_308_692.png → ACK
# Copiada: PAT_767_1501_691.png → BCC
# Copiada: PAT_139_207_342.png → BCC
# Copiada: PAT_1563_2425_443.png → SEK
# Copiada: PAT_842_1606_971.png → BCC
# Copiada: PAT_775_1463_616.png → BCC
# Copiada: PAT_93_361_231.png → SEK
# Copiada: PAT_531_1004_792.png → BCC
# Copiada: PAT_1180_650_843.png → ACK
# Copiada: PAT_1983_4032_502.png → ACK
# Copiada: PAT_1063_271_448.png → ACK
# Copiada: PAT_416_824_540.png → BCC
# Copiada: PAT_520_983_932.png → BCC
# Copiada: PAT_1415_1437_743.png → SEK
# Copiada: PAT_624_1179_323.png → SCC
# Copiada: PAT_517_971_88.png → BCC
# Copiada: PAT_1734_3240_299.png → SEK
# Copiada: PAT_1786_3419_768.png → ACK
# Copiada: PAT_21_31_965.png → NEV
# Copiada: PAT_149_221_679.png → BCC
# Copiada: PAT_148_220_174.png → ACK
# Copiada: PAT_1242_826_903.png → NEV
# Copiada: PAT_85_129_896.png → ACK
# Copiada: PAT_1577_3527_831.png → SEK
# Copiada: PAT_889_1689_986.png → ACK
# Copiada: PAT_645_1461_111.png → BCC
# Copiada: PAT_2140_4726_85.png → ACK
# Copiada: PAT_990_1860_478.png → SCC
# Copiada: PAT_553_1049_461.png → BCC
# Copiada: PAT_1455_1585_690.png → SEK
# Copiada: PAT_744_1404_951.png → BCC
# Copiada: PAT_488_931_321.png → BCC
# Copiada: PAT_87_133_159.png → SEK
# Copiada: PAT_2082_4491_519.png → ACK
# Copiada: PAT_1701_3136_33.png → ACK
# Copiada: PAT_409_2614_24.png → ACK
# Copiada: PAT_763_1439_668.png → ACK
# Copiada: PAT_1219_764_111.png → NEV
# Copiada: PAT_2070_4430_290.png → ACK
# Copiada: PAT_857_1628_916.png → ACK
# Copiada: PAT_1304_1081_84.png → SEK
# Copiada: PAT_115_1138_970.png → MEL
# Copiada: PAT_880_1674_223.png → ACK
# Copiada: PAT_931_1763_617.png → ACK
# Copiada: PAT_267_1061_324.png → BCC
# Copiada: PAT_1026_124_206.png → ACK
# Copiada: PAT_1216_759_365.png → NEV
# Copiada: PAT_389_2600_833.png → ACK
# Copiada: PAT_653_1234_311.png → SCC
# Copiada: PAT_106_158_270.png → BCC
# Copiada: PAT_113_172_610.png → SCC
# Copiada: PAT_1466_1618_147.png → ACK
# Copiada: PAT_486_929_317.png → MEL
# Copiada: PAT_849_1613_824.png → ACK
# Copiada: PAT_104_1756_151.png → BCC
# Copiada: PAT_682_1292_642.png → BCC
# Copiada: PAT_1655_2923_425.png → ACK
# Copiada: PAT_443_864_894.png → BCC
# Copiada: PAT_730_1385_585.png → BCC
# Copiada: PAT_838_1586_622.png → BCC
# Copiada: PAT_913_1730_815.png → BCC
# Copiada: PAT_1978_4004_304.png → SEK
# Copiada: PAT_320_681_410.png → MEL
# Copiada: PAT_1696_3115_917.png → SEK
# Copiada: PAT_309_662_737.png → BCC
# Copiada: PAT_82_125_907.png → BCC
# Copiada: PAT_191_293_699.png → BCC
# Copiada: PAT_619_1175_767.png → BCC
# Copiada: PAT_693_1313_304.png → ACK
# Copiada: PAT_1838_3609_254.png → SEK
# Copiada: PAT_387_786_782.png → SCC
# Copiada: PAT_337_1697_721.png → ACK
# Copiada: PAT_40_56_499.png → BCC
# Copiada: PAT_460_894_429.png → BCC
# Copiada: PAT_650_3858_329.png → SEK
# Copiada: PAT_100_393_595.png → NEV
# Copiada: PAT_1297_1048_353.png → NEV
# Copiada: PAT_223_1067_569.png → ACK
# Copiada: PAT_2114_4609_615.png → ACK
# Copiada: PAT_581_1114_116.png → BCC
# Copiada: PAT_973_1839_34.png → ACK
# Copiada: PAT_1341_1212_539.png → SEK
# Copiada: PAT_479_917_598.png → BCC
# Copiada: PAT_202_308_721.png → ACK
# Copiada: PAT_1246_846_111.png → ACK
# Copiada: PAT_1540_1847_249.png → ACK
# Copiada: PAT_43_61_210.png → SCC
# Copiada: PAT_1913_3818_991.png → ACK
# Copiada: PAT_876_1665_386.png → BCC
# Copiada: PAT_1304_1079_859.png → SEK
# Copiada: PAT_785_1479_108.png → BCC
# Copiada: PAT_214_329_300.png → BCC
# Copiada: PAT_383_779_429.png → BCC
# Copiada: PAT_131_197_260.png → SCC
# Copiada: PAT_359_741_966.png → SCC
# Copiada: PAT_564_1079_31.png → BCC
# Copiada: PAT_695_1314_822.png → BCC
# Copiada: PAT_527_1360_225.png → BCC
# Copiada: PAT_1513_1747_851.png → ACK
# Copiada: PAT_726_1371_397.png → BCC
# Copiada: PAT_774_1462_821.png → BCC
# Copiada: PAT_715_1338_761.png → ACK
# Copiada: PAT_281_1518_571.png → NEV
# Copiada: PAT_503_950_368.png → BCC
# Copiada: PAT_1418_1452_948.png → ACK
# Copiada: PAT_1967_3976_736.png → ACK
# Copiada: PAT_575_1088_134.png → BCC
# Copiada: PAT_97_151_587.png → BCC
# Copiada: PAT_1757_3316_304.png → ACK
# Copiada: PAT_30_41_815.png → BCC
# Copiada: PAT_698_1319_166.png → SCC
# Copiada: PAT_1706_3144_891.png → ACK
# Copiada: PAT_627_1188_503.png → NEV
# Copiada: PAT_886_1684_103.png → ACK
# Copiada: PAT_856_1626_630.png → BCC
# Copiada: PAT_645_1500_364.png → BCC
# Copiada: PAT_135_202_593.png → BCC
# Copiada: PAT_215_330_224.png → SCC
# Copiada: PAT_927_1759_849.png → BCC
# Copiada: PAT_715_1339_508.png → SEK
# Copiada: PAT_90_138_605.png → BCC
# Copiada: PAT_943_1793_787.png → BCC
# Copiada: PAT_482_2928_201.png → SEK
# Copiada: PAT_474_912_879.png → BCC
# Copiada: PAT_279_430_356.png → ACK
# Copiada: PAT_1392_1352_828.png → SEK
# Copiada: PAT_1429_1491_451.png → ACK
# Copiada: PAT_45_66_822.png → MEL
# Copiada: PAT_1913_3815_367.png → ACK
# Copiada: PAT_999_20_401.png → ACK
# Copiada: PAT_1094_381_355.png → ACK
# Copiada: PAT_229_349_141.png → BCC
# Copiada: PAT_219_337_358.png → SCC
# Copiada: PAT_738_1552_502.png → SEK
# Copiada: PAT_985_1856_91.png → BCC
# Copiada: PAT_1657_2932_680.png → NEV
# Copiada: PAT_739_1398_331.png → ACK
# Copiada: PAT_160_249_76.png → BCC
# Copiada: PAT_336_705_711.png → BCC
# Copiada: PAT_1613_2744_603.png → NEV
# Copiada: PAT_181_281_54.png → BCC
# Copiada: PAT_126_192_208.png → ACK
# Copiada: PAT_192_884_310.png → ACK
# Copiada: PAT_172_266_950.png → BCC
# Copiada: PAT_987_1859_724.png → ACK
# Copiada: PAT_1401_1373_881.png → NEV
# Copiada: PAT_1403_1392_848.png → ACK
# Copiada: PAT_190_291_366.png → BCC
# Copiada: PAT_830_1564_740.png → BCC
# Copiada: PAT_360_742_768.png → SCC
# Copiada: PAT_1712_3175_600.png → ACK
# Copiada: PAT_1713_3179_888.png → SEK
# Copiada: PAT_681_1299_458.png → BCC
# Copiada: PAT_747_1409_466.png → ACK
# Copiada: PAT_136_203_436.png → BCC
# Copiada: PAT_1801_3461_351.png → NEV
# Copiada: PAT_498_944_488.png → ACK
# Copiada: PAT_492_937_43.png → SCC
# Copiada: PAT_414_822_420.png → ACK
# Copiada: PAT_754_1429_380.png → MEL
# Copiada: PAT_1407_1402_562.png → ACK
# Copiada: PAT_386_785_536.png → ACK
# Copiada: PAT_1294_1031_466.png → ACK
# Copiada: PAT_273_421_905.png → BCC
# Copiada: PAT_491_934_46.png → SCC
# Copiada: PAT_1708_3156_175.png → ACK
# Copiada: PAT_46_880_140.png → BCC
# Copiada: PAT_1343_1217_404.png → SEK
# Copiada: PAT_326_690_823.png → BCC
# Copiada: PAT_1714_3189_989.png → SEK
